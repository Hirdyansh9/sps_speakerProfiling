# %%
# !unzip '/content/drive/MyDrive/sps/timit_dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SX145.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SX145.TXT
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SI1150.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SI1150.WRD
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SX415.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SX415.WRD
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SI1150.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SI1150.PHN
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SX415.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SX415.PHN
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SX145.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SX145.WAV
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SX55.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SX55.TXT
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SI775.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SI775.TXT
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SX235.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SX235.TXT
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SI1405.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SI1405.WAV
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SX55.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SX55.WAV
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SI775.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SI775.WAV
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SX235.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SX235.WAV
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SI1405.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SI1405.TXT
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SX325.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SX325.TXT
#   inflating: timit_dataset/TRAIN/DR6/MSMR0/SX325.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/MSMR0/._SX325.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX39.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX39.TXT
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX39.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX39.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX309.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX309.PHN
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX309.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX309.WRD
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX129.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX129.TXT
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI2019.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI2019.WRD
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI2019.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI2019.PHN
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX129.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX129.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI759.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI759.PHN
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX219.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX219.WRD
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX399.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX399.TXT
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI759.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI759.WRD
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX219.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX219.PHN
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX399.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX399.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI1389.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI1389.WRD
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI1389.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI1389.PHN
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX219.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX219.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI759.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI759.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX219.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX219.TXT
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX399.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX399.PHN
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX399.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX399.WRD
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI759.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI759.TXT
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI1389.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI1389.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI1389.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI1389.TXT
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX39.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX39.WRD
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX39.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX39.PHN
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI2019.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI2019.TXT
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX309.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX309.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX129.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX129.PHN
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SI2019.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SI2019.WAV
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX129.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX129.WRD
#   inflating: timit_dataset/TRAIN/DR6/FMJU0/SX309.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FMJU0/._SX309.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI1678.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI1678.WAV
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX328.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX328.WAV
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI1048.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI1048.WRD
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI1678.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI1678.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX328.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX328.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI1048.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI1048.PHN
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX238.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX238.WAV
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI2308.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI2308.PHN
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI2308.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI2308.WRD
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX58.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX58.WAV
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX238.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX238.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX58.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX58.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX148.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX148.WAV
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX418.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX418.PHN
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX418.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX418.WRD
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX148.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX148.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX238.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX238.WRD
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX58.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX58.PHN
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI2308.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI2308.WAV
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX238.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX238.PHN
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX58.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX58.WRD
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI2308.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI2308.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX148.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX148.WRD
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX148.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX148.PHN
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX418.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX418.WAV
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX418.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX418.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI1048.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI1048.TXT
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX328.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX328.PHN
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI1678.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI1678.WRD
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SX328.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SX328.WRD
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI1678.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI1678.PHN
#   inflating: timit_dataset/TRAIN/DR6/FKLC1/SI1048.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR6/FKLC1/._SI1048.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX338.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX338.TXT
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX338.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX338.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX248.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX248.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX248.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX248.TXT
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI2048.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI2048.TXT
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX428.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX428.TXT
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX158.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX158.TXT
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI2048.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI2048.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX428.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX428.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX158.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX158.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI788.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI788.PHN
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI788.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI788.WRD
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI1418.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI1418.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX68.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX68.PHN
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX68.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX68.WRD
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI1418.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI1418.TXT
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI2048.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI2048.PHN
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX158.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX158.PHN
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX428.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX428.PHN
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX428.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX428.WRD
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX158.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX158.WRD
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI2048.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI2048.WRD
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI1418.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI1418.PHN
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI1418.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI1418.WRD
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX68.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX68.TXT
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI788.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI788.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX68.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX68.WAV
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SI788.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SI788.TXT
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX338.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX338.WRD
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX338.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX338.PHN
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX248.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX248.PHN
#   inflating: timit_dataset/TRAIN/DR1/FECD0/SX248.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FECD0/._SX248.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX271.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX271.TXT
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX271.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX271.WAV
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI1261.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI1261.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI1261.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI1261.PHN
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX451.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX451.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX451.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX451.PHN
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI631.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI631.WAV
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX91.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX91.PHN
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI631.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI631.TXT
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX91.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX91.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX361.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX361.TXT
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX361.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX361.WAV
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX181.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX181.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI1837.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI1837.PHN
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI1837.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI1837.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX181.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX181.PHN
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI631.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI631.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI631.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI631.PHN
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX91.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX91.TXT
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX91.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX91.WAV
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX181.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX181.TXT
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI1837.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI1837.TXT
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX181.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX181.WAV
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX361.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX361.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX361.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX361.PHN
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI1837.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI1837.WAV
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX271.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX271.PHN
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX271.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX271.WRD
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX451.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX451.TXT
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI1261.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI1261.WAV
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SX451.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SX451.WAV
#   inflating: timit_dataset/TRAIN/DR1/MDAC0/SI1261.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MDAC0/._SI1261.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI1697.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI1697.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX24.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX24.WRD
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI1067.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI1067.PHN
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI1697.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI1697.WAV
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX24.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX24.PHN
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI1067.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI1067.WRD
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX257.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX257.WRD
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX257.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX257.PHN
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX437.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX437.WRD
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX437.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX437.PHN
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX167.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX167.WAV
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX167.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX167.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX77.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX77.WAV
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI2327.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI2327.WRD
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI2327.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI2327.PHN
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX77.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX77.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX437.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX437.WAV
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX167.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX167.PHN
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX167.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX167.WRD
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX437.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX437.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX77.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX77.WRD
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI2327.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI2327.WAV
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX77.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX77.PHN
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI2327.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI2327.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX24.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX24.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI1067.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI1067.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX24.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX24.WAV
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI1697.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI1697.PHN
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI1697.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI1697.WRD
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SI1067.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SI1067.WAV
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX257.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX257.TXT
#   inflating: timit_dataset/TRAIN/DR1/MPSW0/SX257.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MPSW0/._SX257.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX333.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX333.PHN
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX333.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX333.WRD
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX297.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX297.WRD
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX117.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX117.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI2007.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI2007.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX297.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX297.PHN
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX117.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX117.TXT
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI2007.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI2007.TXT
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX207.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX207.TXT
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX387.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX387.PHN
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX387.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX387.WRD
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI747.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI747.TXT
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX207.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX207.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI747.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI747.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI1377.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI1377.PHN
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI1377.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI1377.WRD
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX387.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX387.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI747.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI747.PHN
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX207.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX207.WRD
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX387.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX387.TXT
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI747.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI747.WRD
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX207.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX207.PHN
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI1377.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI1377.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI1377.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI1377.TXT
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX333.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX333.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX333.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX333.TXT
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI2007.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI2007.WRD
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX297.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX297.WAV
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX117.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX117.WRD
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX117.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX117.PHN
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SI2007.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SI2007.PHN
#   inflating: timit_dataset/TRAIN/DR1/FMEM0/SX297.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FMEM0/._SX297.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX258.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX258.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX258.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX258.WAV
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI2238.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI2238.WAV
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI2238.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI2238.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX78.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX78.WRD
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI1608.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI1608.WAV
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX78.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX78.PHN
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI1608.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI1608.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI978.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI978.PHN
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX438.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX438.WAV
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX168.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX168.PHN
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX168.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX168.WRD
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX348.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX348.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI978.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI978.WRD
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX438.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX438.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX348.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX348.WAV
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX78.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX78.WAV
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI1608.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI1608.PHN
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI1608.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI1608.WRD
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX78.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX78.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX438.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX438.WRD
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX438.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX438.PHN
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI978.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI978.WAV
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX168.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX168.WAV
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX348.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX348.PHN
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX348.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX348.WRD
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI978.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI978.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX168.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX168.TXT
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX258.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX258.WRD
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SX258.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SX258.PHN
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI2238.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI2238.PHN
#   inflating: timit_dataset/TRAIN/DR1/FKFB0/SI2238.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FKFB0/._SI2238.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX252.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX252.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX252.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX252.PHN
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI1062.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI1062.PHN
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI1062.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI1062.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI1749.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI1749.PHN
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX72.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX72.TXT
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI1749.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI1749.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX72.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX72.WAV
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI2322.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI2322.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI2322.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI2322.PHN
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX342.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX342.PHN
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX342.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX342.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX162.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX162.TXT
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX432.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX432.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX432.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX432.PHN
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX162.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX162.WAV
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI2322.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI2322.TXT
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI1749.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI1749.WAV
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX72.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX72.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI2322.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI2322.WAV
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI1749.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI1749.TXT
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX72.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX72.PHN
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX432.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX432.TXT
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX342.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX342.WAV
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX432.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX432.WAV
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX162.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX162.PHN
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX162.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX162.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX342.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX342.TXT
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX252.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX252.WAV
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SX252.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SX252.TXT
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI1062.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI1062.WAV
#   inflating: timit_dataset/TRAIN/DR1/MWAD0/SI1062.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/MWAD0/._SI1062.TXT
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX291.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX291.WRD
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX111.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX111.WAV
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI921.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI921.PHN
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX291.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX291.PHN
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI921.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI921.WRD
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX111.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX111.TXT
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI2181.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI2181.PHN
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI2181.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI2181.WRD
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX21.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX21.WRD
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX21.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX21.PHN
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI1402.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI1402.WRD
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI1402.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI1402.PHN
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX201.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX201.TXT
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX381.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX381.PHN
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX381.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX381.WRD
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX201.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX201.WAV
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI1402.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI1402.WAV
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI1402.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI1402.TXT
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX381.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX381.WAV
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX201.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX201.WRD
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX381.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX381.TXT
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX201.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX201.PHN
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX291.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX291.WAV
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX111.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX111.WRD
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI921.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI921.WAV
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX111.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX111.PHN
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI2181.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI2181.TXT
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX291.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX291.TXT
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI921.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI921.TXT
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SI2181.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SI2181.WAV
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX21.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX21.WAV
#   inflating: timit_dataset/TRAIN/DR1/FTBR0/SX21.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FTBR0/._SX21.TXT
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SX312.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SX312.WAV
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SX132.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SX132.PHN
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SX132.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SX132.WRD
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SX312.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SX312.TXT
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SI1510.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SI1510.WRD
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SI1510.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SI1510.PHN
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SX402.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SX402.WAV
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SI1032.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SI1032.WAV
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SX402.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SX402.TXT
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SI1032.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SI1032.TXT
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SX42.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SX42.WRD
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SX222.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SX222.PHN
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SX42.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SX42.PHN
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SX222.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SX222.WRD
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SI2292.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SI2292.PHN
#   inflating: timit_dataset/TRAIN/DR1/FVFB0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR1/FVFB0/._SA2.TXT
# ...
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SI2140.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SI2140.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SI843.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SI843.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX33.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SX33.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SI1468.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SI1468.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SI1468.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SI1468.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SI2140.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SI2140.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SI843.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SI843.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX33.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SX33.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX123.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SX123.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX303.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SX303.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX303.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SX303.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX123.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRLK0/._SX123.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX442.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX442.PHN
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX442.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX442.WRD
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX262.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX262.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX262.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX262.WAV
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX172.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX172.WAV
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI2242.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI2242.WRD
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI982.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI982.PHN
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX172.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX172.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX352.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX352.WRD
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX352.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX352.PHN
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI2242.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI2242.PHN
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI982.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI982.WRD
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI1612.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI1612.WRD
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI1612.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI1612.PHN
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX82.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX82.WRD
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX82.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX82.PHN
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX352.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX352.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI2242.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI2242.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX172.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX172.WRD
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI982.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI982.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX172.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX172.PHN
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX352.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX352.WAV
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI2242.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI2242.WAV
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI982.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI982.WAV
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI1612.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI1612.WAV
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX82.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX82.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SI1612.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SI1612.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX82.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX82.WAV
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX442.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX442.TXT
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX442.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX442.WAV
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX262.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX262.WRD
#   inflating: timit_dataset/TRAIN/DR8/FBCG1/SX262.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/FBCG1/._SX262.PHN
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI861.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI861.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX31.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX31.PHN
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI861.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI861.TXT
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX31.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX31.WRD
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI1491.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI1491.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI1491.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI1491.TXT
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX51.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX51.PHN
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX231.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX231.WRD
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX51.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX51.WRD
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX231.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX231.PHN
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI2121.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI2121.PHN
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI2121.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI2121.WRD
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX141.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX141.WRD
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX141.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX141.PHN
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX411.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX411.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX411.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX411.TXT
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX231.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX231.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX51.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX51.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI2121.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI2121.TXT
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX231.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX231.TXT
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX51.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX51.TXT
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI2121.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI2121.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX141.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX141.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX411.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX411.PHN
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX411.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX411.WRD
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX141.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX141.TXT
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI861.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI861.WRD
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI861.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI861.PHN
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX31.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX31.TXT
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX31.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SX31.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI1491.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI1491.WRD
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI1491.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MKRG0/._SI1491.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI1044.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI1044.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX245.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX245.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI1044.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI1044.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX245.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX245.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX335.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX335.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX335.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX335.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX65.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX65.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI1595.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI1595.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX65.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX65.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI1595.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI1595.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX155.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX155.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX425.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX425.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX425.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX425.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SA1.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SA1.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SA2.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI965.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI965.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX155.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX155.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SA2.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SA2.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SA1.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI965.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI965.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX65.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX65.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI1595.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI1595.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI1595.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI1595.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX65.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX65.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX155.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX155.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI965.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI965.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX425.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX425.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SA2.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SA2.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SA2.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SA2.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI965.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI965.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX155.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX155.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX425.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX425.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SA1.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SA1.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SA1.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SA1.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI1044.WRD
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI1044.WRD
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX245.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX245.TXT
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI1044.PHN
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SI1044.PHN
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX245.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX245.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX335.WAV
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX335.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX335.TXT
#   inflating: __MACOSX/timit_dataset/TRAIN/DR8/MRDM0/._SX335.TXT

# %% [markdown]
# ### Preprocessing CSVs

# %%
import numpy as np
import pandas as pd
import os

# --- Paths ---
SPKR_INFO_CSV = '/content/drive/MyDrive/sps/spkr_info.csv'
TRAIN_CSV     = '/content/drive/MyDrive/sps/train_data.csv'
TEST_CSV      = '/content/drive/MyDrive/sps/test_data.csv'

spkr_df = pd.read_csv(SPKR_INFO_CSV)
train_df = pd.read_csv(TRAIN_CSV)
test_df = pd.read_csv(TEST_CSV)

# %%
spkr_df.drop(columns=['Unnamed: 0', 'RecDate', 'BirthDate','Ht', 'Edu'], inplace=True)

# %%
spkr_df.head()
# Out:
#      ID Sex  DR  Use Race    age  height
# 0  ABC0   M   6  TRN  WHT  25.71  180.34
# 1  ABW0   M   2  TST  WHT  26.90  175.26
# 2  ADC0   M   3  TRN  WHT  31.83  175.26
# 3  ADD0   M   7  TRN  WHT  27.85  187.96
# 4  ADG0   F   4  TST  WHT  26.84  162.56

# %%
spkr_df.rename(columns={
    'ID': 'SpeakerID',
    'Sex': 'Gender',
    'Race': 'Ethnicity'
}, inplace=True)

# %%
spkr_df.head()
# Out:
#   SpeakerID Gender  DR  Use Ethnicity    age  height
# 0      ABC0      M   6  TRN       WHT  25.71  180.34
# 1      ABW0      M   2  TST       WHT  26.90  175.26
# 2      ADC0      M   3  TRN       WHT  31.83  175.26
# 3      ADD0      M   7  TRN       WHT  27.85  187.96
# 4      ADG0      F   4  TST       WHT  26.84  162.56

# %%
spkr_df['SpeakerID'] = spkr_df['SpeakerID'].astype(str).str.upper()

# Filter out unknown/invalid Ethnicity ('???')
initial_len = len(spkr_df)
spkr_df = spkr_df[spkr_df['Ethnicity'].astype(str).str.upper() != '???']

print(f"Filtered {initial_len - len(spkr_df)} rows.")
# Out:
# Filtered 17 rows.

# %%
spkr_df['age'] = pd.to_numeric(spkr_df['age'], errors='coerce')
spkr_df['height'] = pd.to_numeric(spkr_df['height'], errors='coerce')

spkr_df.dropna(subset=['age', 'height'], inplace=True)

print(f"Rows dropped {initial_len - len(spkr_df)}")
# Out:
# Rows dropped 17

# %%
spkr_df.dropna(subset=['Gender', 'Use', 'Ethnicity', 'DR'], inplace=True)
print(f"Rows dropped {initial_len - len(spkr_df)} with missing Gender/Use/Ethnicity/DR.")
# Out:
# Rows dropped 17 with missing Gender/Use/Ethnicity/DR.

# %%
spkr_df['SpeakerID'] = spkr_df['Gender'] + spkr_df['SpeakerID']

# %%
spkr_df.set_index('SpeakerID', inplace=True)

# %%
preprocessed_spkr_df = spkr_df.copy()

# %%
preprocessed_spkr_df.head()
# Out:
#           Gender  DR  Use Ethnicity    age  height
# SpeakerID
# ABC0           M   6  TRN       WHT  25.71  180.34
# ABW0           M   2  TST       WHT  26.90  175.26
# ADC0           M   3  TRN       WHT  31.83  175.26
# ADD0           M   7  TRN       WHT  27.85  187.96
# ADG0           F   4  TST       WHT  26.84  162.56

# %%
train_df.drop(columns=['path_from_data_dir_windows'], inplace=True)
test_df.drop(columns=['path_from_data_dir_windows'], inplace=True)

# %%
train_df.rename(columns={
    'speaker_id': 'SpeakerID',
    'Sex': 'Gender',
    'test_or_train': 'Use',
    'path_from_data_dir': 'FilePath',
    'dialect_region': 'DR'
}, inplace=True)

test_df.rename(columns={
    'speaker_id': 'SpeakerID',
    'Sex': 'Gender',
    'test_or_train': 'Use',
    'path_from_data_dir': 'FilePath',
    'dialect_region': 'DR'
}, inplace=True)

# %%
train_df.head()
# Out:
#    index    Use   DR SpeakerID       filename                       FilePath  \
# 0      1  TRAIN  DR4     MMDM0  SI681.WAV.wav  TRAIN/DR4/MMDM0/SI681.WAV.wav
# 1      2  TRAIN  DR4     MMDM0     SI1311.PHN     TRAIN/DR4/MMDM0/SI1311.PHN
# 2      3  TRAIN  DR4     MMDM0     SI1311.WRD     TRAIN/DR4/MMDM0/SI1311.WRD
# 3      4  TRAIN  DR4     MMDM0      SX321.PHN      TRAIN/DR4/MMDM0/SX321.PHN
# 4      5  TRAIN  DR4     MMDM0      SX321.WRD      TRAIN/DR4/MMDM0/SX321.WRD
#
#    is_converted_audio  is_audio  is_word_file is_phonetic_file  \
# 0                True      True         False            False
# 1               False     False         False             True
# 2               False     False          True            False
# 3               False     False         False             True
# 4               False     False          True            False
#
#    is_sentence_file
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
test_df.head()
# Out:
#    index   Use   DR SpeakerID       filename                      FilePath  \
# 0      1  TEST  DR4     MGMM0      SX139.WAV      TEST/DR4/MGMM0/SX139.WAV
# 1      2  TEST  DR4     MGMM0  SX139.WAV.wav  TEST/DR4/MGMM0/SX139.WAV.wav
# 2      3  TEST  DR4     MGMM0      SX139.TXT      TEST/DR4/MGMM0/SX139.TXT
# 3      4  TEST  DR4     MGMM0      SI499.WRD      TEST/DR4/MGMM0/SI499.WRD
# 4      5  TEST  DR4     MGMM0      SX319.WRD      TEST/DR4/MGMM0/SX319.WRD
#
#    is_converted_audio  is_audio  is_word_file  is_phonetic_file  \
# 0               False      True         False             False
# 1                True      True         False             False
# 2               False     False         False             False
# 3               False     False          True             False
# 4               False     False          True             False
#
#    is_sentence_file
# 0             False
# 1             False
# 2              True
# 3             False
# 4             False

# %%
train_df['SpeakerID'] = train_df['SpeakerID'].astype(str).str.upper()
train_df['FilePath'] = train_df['FilePath'].astype(str).str.strip()

# Keep rows where FilePath ends with .WAV (case-insensitive)
initial_len = len(train_df)

train_df = train_df[~train_df['filename'].str.endswith('.WAV.wav')]
preprocessed_train_df = train_df[train_df['FilePath'].str.contains(r'\.WAV$', case=False, regex=True, na=False)].copy()

print(f"Filtered {initial_len - len(preprocessed_train_df)} non-.WAV entries.")
print(f"Cleaned file list ready: {len(preprocessed_train_df)} audio utterances.")

preprocessed_train_df.head()
# Out:
# Filtered 18480 non-.WAV entries.
# Cleaned file list ready: 4620 audio utterances.
#     index    Use   DR SpeakerID   filename                   FilePath  \
# 7       8  TRAIN  DR4     MMDM0  SI681.WAV  TRAIN/DR4/MMDM0/SI681.WAV
# 17     18  TRAIN  DR4     MMDM0    SA2.WAV    TRAIN/DR4/MMDM0/SA2.WAV
# 19     20  TRAIN  DR4     MMDM0  SX411.WAV  TRAIN/DR4/MMDM0/SX411.WAV
# 22     23  TRAIN  DR4     MMDM0    SA1.WAV    TRAIN/DR4/MMDM0/SA1.WAV
# 25     26  TRAIN  DR4     MMDM0  SX231.WAV  TRAIN/DR4/MMDM0/SX231.WAV
#
#     is_converted_audio  is_audio  is_word_file is_phonetic_file  \
# 7                False      True         False            False
# 17               False      True         False            False
# 19               False      True         False            False
# 22               False      True         False            False
# 25               False      True         False            False
#
#     is_sentence_file
# 7              False
# 17             False
# 19             False
# 22             False
# 25             False

# %%
test_df['SpeakerID'] = test_df['SpeakerID'].astype(str).str.upper()
test_df['FilePath'] = test_df['FilePath'].astype(str).str.strip()

# Keep rows where FilePath ends with .WAV (case-insensitive)
initial_len = len(test_df)

test_df = test_df[~test_df['FilePath'].str.endswith('.WAV.wav')]
preprocessed_test_df = test_df[test_df['FilePath'].str.contains(r'\.WAV$', case=False, regex=True, na=False)].copy()

print(f"Filtered {initial_len - len(preprocessed_test_df)} non-.WAV entries.")
print(f"Cleaned file list ready: {len(preprocessed_test_df)} audio utterances.")

preprocessed_test_df.head()
# Out:
# Filtered 6720 non-.WAV entries.
# Cleaned file list ready: 1680 audio utterances.
#     index   Use   DR SpeakerID   filename                  FilePath  \
# 0       1  TEST  DR4     MGMM0  SX139.WAV  TEST/DR4/MGMM0/SX139.WAV
# 17     18  TEST  DR4     MGMM0    SA2.WAV    TEST/DR4/MGMM0/SA2.WAV
# 20     21  TEST  DR4     MGMM0  SX229.WAV  TEST/DR4/MGMM0/SX229.WAV
# 23     24  TEST  DR4     MGMM0    SA1.WAV    TEST/DR4/MGMM0/SA1.WAV
# 24     25  TEST  DR4     MGMM0   SX49.WAV   TEST/DR4/MGMM0/SX49.WAV
#
#     is_converted_audio  is_audio  is_word_file  is_phonetic_file  \
# 0                False      True         False             False
# 17               False      True         False             False
# 20               False      True         False             False
# 23               False      True         False             False
# 24               False      True         False             False
#
#     is_sentence_file
# 0              False
# 17             False
# 20             False
# 23             False
# 24             False

# %%
if 'preprocessed_spkr_df' not in locals() or 'preprocessed_train_df' not in locals() or 'preprocessed_test_df' not in locals():
    raise NameError("One or more preprocessed dataframes (spkr, train, test) not found.")

if preprocessed_spkr_df.index.name != 'SpeakerID':
    if 'SpeakerID' in preprocessed_spkr_df.columns:
         preprocessed_spkr_df.set_index('SpeakerID', inplace=True)
    else:
        raise ValueError("SpeakerID not found as index or column in preprocessed_spkr_df")

if 'SpeakerID' not in preprocessed_train_df.columns or 'SpeakerID' not in preprocessed_test_df.columns:
    raise ValueError("SpeakerID column not found in preprocessed train/test df.")

# %%
valid_speakers = set(preprocessed_spkr_df.index)
train_files_valid_spk = preprocessed_train_df[preprocessed_train_df['SpeakerID'].isin(valid_speakers)].copy()
test_files_valid_spk = preprocessed_test_df[preprocessed_test_df['SpeakerID'].isin(valid_speakers)].copy()
print(f"Utterances with valid speakers before merge: Train={len(train_files_valid_spk)}, Test={len(test_files_valid_spk)}")

# %%
train_df_merged = pd.merge(
    train_files_valid_spk,
    preprocessed_spkr_df, # Contains targets and 'Use' column
    left_on='SpeakerID',
    right_index=True,     # Merge on spkr_df's index
    how='left'
)

test_df_merged = pd.merge(
    test_files_valid_spk,
    preprocessed_spkr_df,
    left_on='SpeakerID',
    right_index=True,
    how='left'
)

# %%
# --- Final Filtering based on 'Use' flag and NaNs ---
target_cols = ['age', 'Gender', 'height', 'Ethnicity']
required_final_cols = ['FilePath', 'SpeakerID', 'Use'] + target_cols
initial_train_len = len(train_df_merged)
initial_test_len = len(test_df_merged)

train_df_merged.dropna(subset=required_final_cols, inplace=True)
test_df_merged.dropna(subset=required_final_cols, inplace=True)

# %%
# Separate final train/test based on the 'Use' column from speaker info
train_df_final = train_df_merged[train_df_merged['Use'].str.upper() == 'TRN'].copy()
test_df_final = test_df_merged[test_df_merged['Use'].str.upper() == 'TST'].copy()

print(f"Final Merged Train DF: {len(train_df_final)} utterances (removed {initial_train_len - len(train_df_final)} non-TRN or NaN rows).")
print(f"Final Merged Test DF : {len(test_df_final)} utterances (removed {initial_test_len - len(test_df_final)} non-TST or NaN rows).")

# %%
train_df_final.head()

# %%
test_df_final.head()

# %%
os.remove('/content/drive/MyDrive/sps/preprocessed_spkr_info.csv')
os.remove('/content/drive/MyDrive/sps/preprocessed_train_data.csv')
os.remove('/content/drive/MyDrive/sps/preprocessed_test_data.csv')

# %%
train_df_final.to_csv('/content/drive/MyDrive/sps/final_train_data_merged.csv', index=False)
test_df_final.to_csv('/content/drive/MyDrive/sps/final_test_data_merged.csv', index=False)

# %% [markdown]
# ### Preprocessing TIMIT

# %%
import pandas as pd
import os

SPKR_INFO_CSV = '/content/drive/MyDrive/sps/preprocessed_spkr_info.csv'
TRAIN_CSV     = '/content/drive/MyDrive/sps/preprocessed_train_data.csv'
TEST_CSV      = '/content/drive/MyDrive/sps/preprocessed_test_data.csv'
AUDIO_ROOT_DIR = '/content/timit_dataset/'

# %%
train_df = pd.read_csv(TRAIN_CSV)
test_df = pd.read_csv(TEST_CSV)

all_filepaths = set(train_df_final['FilePath']).union(set(test_df_final['FilePath']))
print(f"Total unique file paths to keep: {len(all_filepaths)}")
# Out:
# 6300

# %%
# print(all_filepaths)

# %%
# count = 0
# for filename in all_filepaths:
#     filepath = os.path.join(AUDIO_ROOT_DIR, filename)
#     # print(filepath)

#     if os.path.isfile(filepath) and filename not in all_filepaths:
#       try:
#           os.remove(filepath)
#           print(f"Deleted file: {filepath}")
#           count = count + 1
#       except OSError as e:
#           print(f"Error deleting file {filepath}: {e}")

# print(f"Files deleted = {count}")

# %%
from tqdm.notebook import tqdm

if 'AUDIO_ROOT_DIR' not in locals() or not os.path.isdir(AUDIO_ROOT_DIR):
    print(f"ERROR: AUDIO_ROOT_DIR ('{AUDIO_ROOT_DIR}') is not defined or not found.")

# %%
try:
    if 'FilePath' not in train_df.columns or 'FilePath' not in test_df.columns:
        raise KeyError("Column 'FilePath' not found in preprocessed dataframes.")

    valid_paths_train = set(train_df['FilePath'])
    valid_paths_test = set(test_df['FilePath'])
    valid_relative_paths = valid_paths_train.union(valid_paths_test)
    print(f"  Found {len(valid_relative_paths)} unique valid relative WAV paths to keep.")

    if not valid_relative_paths:
        raise ValueError("Set of valid paths is empty. Cannot proceed.")

except Exception as e:
    print(f"Error creating valid path set: {e}")
    valid_relative_paths = set()

print(f"\nScanning directory tree: {AUDIO_ROOT_DIR}...")
files_to_remove = []
files_to_keep_count = 0

for root, dirs, files in os.walk(AUDIO_ROOT_DIR):
    for filename in files:
        full_path = os.path.join(root, filename)
        relative_path = os.path.relpath(full_path, AUDIO_ROOT_DIR).replace(os.path.sep, '/')

        is_valid_wav = filename.upper().endswith('.WAV') and relative_path in valid_relative_paths

        if not is_valid_wav:
            files_to_remove.append(full_path)
        else:
            files_to_keep_count += 1

print(f"\nScan complete.")
print(f"  Found {files_to_keep_count} WAV files matching the preprocessed CSVs.")
print(f"  Identified {len(files_to_remove)} files to remove (non-WAV or unused WAV).")
# Out:
#   Found 6300 unique valid relative WAV paths to keep.
#
# Scanning directory tree: /content/timit_dataset/...
#
# Scan complete.
#   Found 6300 WAV files matching the preprocessed CSVs.
#   Identified 18927 files to remove (non-WAV or unused WAV).

# %%
perform_deletion = True # True to enable deletion
if files_to_remove:
    if perform_deletion:
        print("\n--- DELETING FILES ---")
        deleted_count = 0
        error_count = 0
        for file_path in tqdm(files_to_remove, desc="Deleting files"):
            try:
                os.remove(file_path)
                deleted_count += 1
            except OSError as e:
                print(f"  Error deleting {file_path}: {e}")
                error_count += 1
        print(f"--- File Deletion Finished ---")
        print(f"  Successfully deleted: {deleted_count} files.")
        print(f"  Errors occurred for: {error_count} files.")

    else:
        print("\n--- Dry Run: Files Marked for Removal ---")
        for i, f in enumerate(files_to_remove):
             if i < 20:
                 print(f"  Would delete: {f}")
             elif i == 20:
                 print("    ...")
                 break
        print(f"\nTotal files marked for removal: {len(files_to_remove)}")
        print("\nSet 'perform_deletion = True' in the script to actually delete these files.")
else:
    print("\nNo files marked for removal. Directory seems clean according to CSVs.")

print("\n--- Directory Cleaning Script Finished ---")
# Out:
# --- DELETING FILES ---
# Deleting files:   0%|          | 0/18927 [00:00<?, ?it/s]
# --- File Deletion Finished ---
#   Successfully deleted: 18927 files.
#   Errors occurred for: 0 files.
#
# --- Directory Cleaning Script Finished ---

# %%
import shutil
shutil.make_archive('/content/drive/MyDrive/sps/preprocessed_timit_dataset', 'zip', '/content/timit_dataset')
# Out:
# '/content/drive/MyDrive/sps/preprocessed_timit_dataset.zip'

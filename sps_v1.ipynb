# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir 'timit_dataset'
# !unzip '/content/drive/MyDrive/sps/preprocessed_timit_dataset.zip' -d timit_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: timit_dataset/TRAIN/DR3/MMSM0/SX206.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMSM0/SX26.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMSM0/SI476.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMSM0/SI1106.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMSM0/SX386.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMSM0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMSM0/SI1736.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMSM0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMSM0/SX116.WAV
#   inflating: timit_dataset/TRAIN/DR3/FEME0/SX335.WAV
#   inflating: timit_dataset/TRAIN/DR3/FEME0/SX65.WAV
#   inflating: timit_dataset/TRAIN/DR3/FEME0/SI2135.WAV
#   inflating: timit_dataset/TRAIN/DR3/FEME0/SX155.WAV
#   inflating: timit_dataset/TRAIN/DR3/FEME0/SI1505.WAV
#   inflating: timit_dataset/TRAIN/DR3/FEME0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FEME0/SX245.WAV
#   inflating: timit_dataset/TRAIN/DR3/FEME0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FEME0/SI875.WAV
#   inflating: timit_dataset/TRAIN/DR3/FEME0/SX425.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLG0/SX359.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLG0/SX179.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLG0/SI1889.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLG0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLG0/SI1506.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLG0/SX89.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLG0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLG0/SX269.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLG0/SX449.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLG0/SI2306.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSLS0/SX426.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSLS0/SX156.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSLS0/SI1686.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSLS0/SX246.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSLS0/SI1056.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSLS0/SI2316.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSLS0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSLS0/SX202.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSLS0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSLS0/SX66.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJLG1/SX382.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJLG1/SX292.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJLG1/SX22.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJLG1/SX112.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJLG1/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJLG1/SX202.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJLG1/SI1012.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJLG1/SI1642.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJLG1/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJLG1/SI2272.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDHS0/SI900.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDHS0/SX180.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDHS0/SX270.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDHS0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDHS0/SX90.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDHS0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDHS0/SI1530.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDHS0/SX450.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDHS0/SI2160.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDHS0/SX360.WAV
#   inflating: timit_dataset/TRAIN/DR3/MVJH0/SX296.WAV
#   inflating: timit_dataset/TRAIN/DR3/MVJH0/SX206.WAV
#   inflating: timit_dataset/TRAIN/DR3/MVJH0/SX26.WAV
#   inflating: timit_dataset/TRAIN/DR3/MVJH0/SI2186.WAV
#   inflating: timit_dataset/TRAIN/DR3/MVJH0/SI1556.WAV
#   inflating: timit_dataset/TRAIN/DR3/MVJH0/SX386.WAV
#   inflating: timit_dataset/TRAIN/DR3/MVJH0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MVJH0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MVJH0/SI926.WAV
#   inflating: timit_dataset/TRAIN/DR3/MVJH0/SX116.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRDS0/SI1797.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRDS0/SX267.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRDS0/SI537.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRDS0/SX357.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRDS0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRDS0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRDS0/SX447.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRDS0/SI1167.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRDS0/SX87.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRDS0/SX177.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTJ0/SX52.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTJ0/SX322.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTJ0/SX142.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTJ0/SI1551.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTJ0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTJ0/SI2032.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTJ0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTJ0/SX412.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTJ0/SX232.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTJ0/SI772.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRBC0/SX59.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRBC0/SI1665.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRBC0/SX149.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRBC0/SX239.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRBC0/SI1859.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRBC0/SX419.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRBC0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRBC0/SX329.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRBC0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRBC0/SI599.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCEF0/SX415.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCEF0/SI842.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCEF0/SX55.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCEF0/SX325.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCEF0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCEF0/SX145.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCEF0/SI1135.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCEF0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCEF0/SX235.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCEF0/SI1765.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSKC0/SX426.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSKC0/SX156.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSKC0/SX246.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSKC0/SI2046.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSKC0/SX336.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSKC0/SI786.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSKC0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSKC0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSKC0/SI1416.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSKC0/SX66.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJDA0/SX311.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJDA0/SI2291.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJDA0/SI1661.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJDA0/SX41.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJDA0/SI1031.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJDA0/SX131.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJDA0/SX401.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJDA0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJDA0/SX221.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJDA0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDLC0/SI2025.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDLC0/SX225.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDLC0/SX405.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDLC0/SX45.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDLC0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDLC0/SX315.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDLC0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDLC0/SX135.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDLC0/SI1395.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDLC0/SI765.WAV
#   inflating: timit_dataset/TRAIN/DR3/FNTB0/SI1203.WAV
#   inflating: timit_dataset/TRAIN/DR3/FNTB0/SX213.WAV
#   inflating: timit_dataset/TRAIN/DR3/FNTB0/SX303.WAV
#   inflating: timit_dataset/TRAIN/DR3/FNTB0/SI679.WAV
#   inflating: timit_dataset/TRAIN/DR3/FNTB0/SX393.WAV
#   inflating: timit_dataset/TRAIN/DR3/FNTB0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FNTB0/SX33.WAV
#   inflating: timit_dataset/TRAIN/DR3/FNTB0/SI573.WAV
#   inflating: timit_dataset/TRAIN/DR3/FNTB0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FNTB0/SX123.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJJB0/SI1139.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJJB0/SX59.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJJB0/SI1769.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJJB0/SX149.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJJB0/SX239.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJJB0/SX419.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJJB0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJJB0/SX329.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJJB0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJJB0/SI1277.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDC0/SX122.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDC0/SX212.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDC0/SI1292.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDC0/SI1922.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDC0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDC0/SX302.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDC0/SI662.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDC0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDC0/SX32.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDC0/SX392.WAV
#   inflating: timit_dataset/TRAIN/DR3/MPRD0/SI801.WAV
#   inflating: timit_dataset/TRAIN/DR3/MPRD0/SX81.WAV
#   inflating: timit_dataset/TRAIN/DR3/MPRD0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MPRD0/SI2061.WAV
#   inflating: timit_dataset/TRAIN/DR3/MPRD0/SX261.WAV
#   inflating: timit_dataset/TRAIN/DR3/MPRD0/SX351.WAV
#   inflating: timit_dataset/TRAIN/DR3/MPRD0/SX441.WAV
#   inflating: timit_dataset/TRAIN/DR3/MPRD0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MPRD0/SX171.WAV
#   inflating: timit_dataset/TRAIN/DR3/MPRD0/SI1431.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLR0/SX331.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLR0/SX151.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLR0/SX241.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLR0/SI601.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLR0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLR0/SI1231.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLR0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLR0/SX61.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLR0/SX421.WAV
#   inflating: timit_dataset/TRAIN/DR3/FJLR0/SI1861.WAV
#   inflating: timit_dataset/TRAIN/DR3/FALK0/SX186.WAV
#   inflating: timit_dataset/TRAIN/DR3/FALK0/SX6.WAV
#   inflating: timit_dataset/TRAIN/DR3/FALK0/SI658.WAV
#   inflating: timit_dataset/TRAIN/DR3/FALK0/SX366.WAV
#   inflating: timit_dataset/TRAIN/DR3/FALK0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FALK0/SX96.WAV
#   inflating: timit_dataset/TRAIN/DR3/FALK0/SI456.WAV
#   inflating: timit_dataset/TRAIN/DR3/FALK0/SX276.WAV
#   inflating: timit_dataset/TRAIN/DR3/FALK0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FALK0/SI1086.WAV
#   inflating: timit_dataset/TRAIN/DR3/MBEF0/SX381.WAV
#   inflating: timit_dataset/TRAIN/DR3/MBEF0/SI651.WAV
#   inflating: timit_dataset/TRAIN/DR3/MBEF0/SX21.WAV
#   inflating: timit_dataset/TRAIN/DR3/MBEF0/SI1281.WAV
#   inflating: timit_dataset/TRAIN/DR3/MBEF0/SX111.WAV
#   inflating: timit_dataset/TRAIN/DR3/MBEF0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MBEF0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MBEF0/SX291.WAV
#   inflating: timit_dataset/TRAIN/DR3/MBEF0/SX201.WAV
#   inflating: timit_dataset/TRAIN/DR3/MBEF0/SI1911.WAV
#   inflating: timit_dataset/TRAIN/DR3/MILB0/SX183.WAV
#   inflating: timit_dataset/TRAIN/DR3/MILB0/SX363.WAV
#   inflating: timit_dataset/TRAIN/DR3/MILB0/SX273.WAV
#   inflating: timit_dataset/TRAIN/DR3/MILB0/SX93.WAV
#   inflating: timit_dataset/TRAIN/DR3/MILB0/SI807.WAV
#   inflating: timit_dataset/TRAIN/DR3/MILB0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MILB0/SX3.WAV
#   inflating: timit_dataset/TRAIN/DR3/MILB0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MILB0/SI903.WAV
#   inflating: timit_dataset/TRAIN/DR3/MILB0/SI2163.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDEF0/SI1123.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDEF0/SX213.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDEF0/SX303.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDEF0/SX393.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDEF0/SI2193.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDEF0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDEF0/SI1563.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDEF0/SX33.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDEF0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDEF0/SX123.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAM0/SX427.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAM0/SI2227.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAM0/SI1597.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAM0/SI1668.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAM0/SX247.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAM0/SX157.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAM0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAM0/SX337.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAM0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAM0/SX67.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAPV0/SI1293.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAPV0/SX213.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAPV0/SX303.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAPV0/SX393.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAPV0/SI1923.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAPV0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAPV0/SI663.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAPV0/SX33.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAPV0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAPV0/SX123.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDTB0/SX210.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDTB0/SX120.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDTB0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDTB0/SX321.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDTB0/SI570.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDTB0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDTB0/SX300.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDTB0/SI1830.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDTB0/SI1200.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDTB0/SX390.WAV
#   inflating: timit_dataset/TRAIN/DR3/MLNS0/SX57.WAV
#   inflating: timit_dataset/TRAIN/DR3/MLNS0/SX327.WAV
#   inflating: timit_dataset/TRAIN/DR3/MLNS0/SI777.WAV
#   inflating: timit_dataset/TRAIN/DR3/MLNS0/SX417.WAV
#   inflating: timit_dataset/TRAIN/DR3/MLNS0/SX237.WAV
#   inflating: timit_dataset/TRAIN/DR3/MLNS0/SI2037.WAV
#   inflating: timit_dataset/TRAIN/DR3/MLNS0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MLNS0/SI1407.WAV
#   inflating: timit_dataset/TRAIN/DR3/MLNS0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MLNS0/SX147.WAV
#   inflating: timit_dataset/TRAIN/DR3/FDJH0/SX35.WAV
#   inflating: timit_dataset/TRAIN/DR3/FDJH0/SX305.WAV
#   inflating: timit_dataset/TRAIN/DR3/FDJH0/SX395.WAV
#   inflating: timit_dataset/TRAIN/DR3/FDJH0/SI2195.WAV
#   inflating: timit_dataset/TRAIN/DR3/FDJH0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FDJH0/SI935.WAV
#   inflating: timit_dataset/TRAIN/DR3/FDJH0/SX215.WAV
#   inflating: timit_dataset/TRAIN/DR3/FDJH0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FDJH0/SX125.WAV
#   inflating: timit_dataset/TRAIN/DR3/FDJH0/SI1565.WAV
#   inflating: timit_dataset/TRAIN/DR3/MGAF0/SX382.WAV
#   inflating: timit_dataset/TRAIN/DR3/MGAF0/SX292.WAV
#   inflating: timit_dataset/TRAIN/DR3/MGAF0/SX22.WAV
#   inflating: timit_dataset/TRAIN/DR3/MGAF0/SX112.WAV
#   inflating: timit_dataset/TRAIN/DR3/MGAF0/SI1282.WAV
#   inflating: timit_dataset/TRAIN/DR3/MGAF0/SI1912.WAV
#   inflating: timit_dataset/TRAIN/DR3/MGAF0/SI652.WAV
#   inflating: timit_dataset/TRAIN/DR3/MGAF0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MGAF0/SX202.WAV
#   inflating: timit_dataset/TRAIN/DR3/MGAF0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLJD0/SI886.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLJD0/SI2146.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLJD0/SX256.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLJD0/SX346.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLJD0/SI1516.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLJD0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLJD0/SX76.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLJD0/SX436.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLJD0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLJD0/SX166.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKR0/SX452.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKR0/SX272.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKR0/SI1982.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKR0/SI1352.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKR0/SX362.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKR0/SX92.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKR0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKR0/SX182.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKR0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKR0/SI722.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDD0/SX253.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDD0/SX163.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDD0/SI2143.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDD0/SX73.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDD0/SX343.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDD0/SI883.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDD0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDD0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDD0/SI1513.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCDD0/SX433.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHMR0/SI489.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHMR0/SX129.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHMR0/SX219.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHMR0/SX39.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHMR0/SX309.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHMR0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHMR0/SI1119.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHMR0/SI1692.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHMR0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHMR0/SX399.WAV
#   inflating: timit_dataset/TRAIN/DR3/MADC0/SX197.WAV
#   inflating: timit_dataset/TRAIN/DR3/MADC0/SI1367.WAV
#   inflating: timit_dataset/TRAIN/DR3/MADC0/SI737.WAV
#   inflating: timit_dataset/TRAIN/DR3/MADC0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MADC0/SX107.WAV
#   inflating: timit_dataset/TRAIN/DR3/MADC0/SI1997.WAV
#   inflating: timit_dataset/TRAIN/DR3/MADC0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MADC0/SX17.WAV
#   inflating: timit_dataset/TRAIN/DR3/MADC0/SX377.WAV
#   inflating: timit_dataset/TRAIN/DR3/MADC0/SX287.WAV
#   inflating: timit_dataset/TRAIN/DR3/FMJF0/SX444.WAV
#   inflating: timit_dataset/TRAIN/DR3/FMJF0/SI1254.WAV
#   inflating: timit_dataset/TRAIN/DR3/FMJF0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FMJF0/SI1884.WAV
#   inflating: timit_dataset/TRAIN/DR3/FMJF0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FMJF0/SX264.WAV
#   inflating: timit_dataset/TRAIN/DR3/FMJF0/SX354.WAV
#   inflating: timit_dataset/TRAIN/DR3/FMJF0/SX84.WAV
#   inflating: timit_dataset/TRAIN/DR3/FMJF0/SI624.WAV
#   inflating: timit_dataset/TRAIN/DR3/FMJF0/SX174.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRJB1/SX30.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRJB1/SI1413.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRJB1/SX210.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRJB1/SX120.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRJB1/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRJB1/SI2021.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRJB1/SI1020.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRJB1/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRJB1/SX300.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRJB1/SX390.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHJB0/SI1017.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHJB0/SI1647.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHJB0/SX297.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHJB0/SX27.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHJB0/SX387.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHJB0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHJB0/SX207.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHJB0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHJB0/SI2277.WAV
#   inflating: timit_dataset/TRAIN/DR3/MHJB0/SX117.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTC0/SI1458.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTC0/SI2088.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTC0/SX288.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTC0/SX198.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTC0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTC0/SX108.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTC0/SX18.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTC0/SI828.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTC0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRTC0/SX378.WAV
#   inflating: timit_dataset/TRAIN/DR3/MFMC0/SX52.WAV
#   inflating: timit_dataset/TRAIN/DR3/MFMC0/SX322.WAV
#   inflating: timit_dataset/TRAIN/DR3/MFMC0/SX142.WAV
#   inflating: timit_dataset/TRAIN/DR3/MFMC0/SI1132.WAV
#   inflating: timit_dataset/TRAIN/DR3/MFMC0/SI1762.WAV
#   inflating: timit_dataset/TRAIN/DR3/MFMC0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MFMC0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MFMC0/SX412.WAV
#   inflating: timit_dataset/TRAIN/DR3/MFMC0/SX232.WAV
#   inflating: timit_dataset/TRAIN/DR3/MFMC0/SI502.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLTM0/SX440.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLTM0/SI2330.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLTM0/SX350.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLTM0/SI1070.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLTM0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLTM0/SI1700.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLTM0/SX80.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLTM0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLTM0/SX170.WAV
#   inflating: timit_dataset/TRAIN/DR3/FLTM0/SX260.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRWA0/SX253.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRWA0/SX163.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRWA0/SX73.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRWA0/SX343.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRWA0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRWA0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRWA0/SI1603.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRWA0/SI973.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRWA0/SI2233.WAV
#   inflating: timit_dataset/TRAIN/DR3/MRWA0/SX433.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKB0/SX296.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKB0/SX206.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKB0/SI1646.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKB0/SX26.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKB0/SI2276.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKB0/SX386.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKB0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKB0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKB0/SX116.WAV
#   inflating: timit_dataset/TRAIN/DR3/MAKB0/SI1016.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCAL0/SX418.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCAL0/SI1768.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCAL0/SX238.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCAL0/SX58.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCAL0/SI508.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCAL0/SI1138.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCAL0/SX328.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCAL0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCAL0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MCAL0/SX148.WAV
#   inflating: timit_dataset/TRAIN/DR3/MREE0/SI1104.WAV
#   inflating: timit_dataset/TRAIN/DR3/MREE0/SX114.WAV
#   inflating: timit_dataset/TRAIN/DR3/MREE0/SX24.WAV
#   inflating: timit_dataset/TRAIN/DR3/MREE0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MREE0/SX294.WAV
#   inflating: timit_dataset/TRAIN/DR3/MREE0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MREE0/SI1959.WAV
#   inflating: timit_dataset/TRAIN/DR3/MREE0/SI1734.WAV
#   inflating: timit_dataset/TRAIN/DR3/MREE0/SX204.WAV
#   inflating: timit_dataset/TRAIN/DR3/MREE0/SX384.WAV
#   inflating: timit_dataset/TRAIN/DR3/FPAZ0/SI963.WAV
#   inflating: timit_dataset/TRAIN/DR3/FPAZ0/SI2223.WAV
#   inflating: timit_dataset/TRAIN/DR3/FPAZ0/SX243.WAV
#   inflating: timit_dataset/TRAIN/DR3/FPAZ0/SX423.WAV
#   inflating: timit_dataset/TRAIN/DR3/FPAZ0/SX153.WAV
#   inflating: timit_dataset/TRAIN/DR3/FPAZ0/SX27.WAV
#   inflating: timit_dataset/TRAIN/DR3/FPAZ0/SX63.WAV
#   inflating: timit_dataset/TRAIN/DR3/FPAZ0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FPAZ0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FPAZ0/SI1593.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDJM0/SI2085.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDJM0/SI825.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDJM0/SX105.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDJM0/SX285.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDJM0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDJM0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDJM0/SX195.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDJM0/SX15.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDJM0/SX375.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDJM0/SI1455.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWDK0/SI1436.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWDK0/SX266.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWDK0/SX356.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWDK0/SX86.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWDK0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWDK0/SX446.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWDK0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWDK0/SI806.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWDK0/SX176.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWDK0/SI2017.WAV
#   inflating: timit_dataset/TRAIN/DR3/MKLS1/SI2175.WAV
#   inflating: timit_dataset/TRAIN/DR3/MKLS1/SI1545.WAV
#   inflating: timit_dataset/TRAIN/DR3/MKLS1/SX105.WAV
#   inflating: timit_dataset/TRAIN/DR3/MKLS1/SX285.WAV
#   inflating: timit_dataset/TRAIN/DR3/MKLS1/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MKLS1/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MKLS1/SI915.WAV
#   inflating: timit_dataset/TRAIN/DR3/MKLS1/SX195.WAV
#   inflating: timit_dataset/TRAIN/DR3/MKLS1/SX15.WAV
#   inflating: timit_dataset/TRAIN/DR3/MKLS1/SX375.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWGR0/SX256.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWGR0/SI2236.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWGR0/SX346.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWGR0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWGR0/SX76.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWGR0/SX436.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWGR0/SI976.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWGR0/SI1606.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWGR0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MWGR0/SX166.WAV
#   inflating: timit_dataset/TRAIN/DR3/FGRW0/SX342.WAV
#   inflating: timit_dataset/TRAIN/DR3/FGRW0/SI1782.WAV
#   inflating: timit_dataset/TRAIN/DR3/FGRW0/SX432.WAV
#   inflating: timit_dataset/TRAIN/DR3/FGRW0/SI1152.WAV
#   inflating: timit_dataset/TRAIN/DR3/FGRW0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FGRW0/SX252.WAV
#   inflating: timit_dataset/TRAIN/DR3/FGRW0/SI1990.WAV
#   inflating: timit_dataset/TRAIN/DR3/FGRW0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FGRW0/SX72.WAV
#   inflating: timit_dataset/TRAIN/DR3/FGRW0/SX162.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMJB1/SX418.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMJB1/SX238.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMJB1/SX58.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMJB1/SI2038.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMJB1/SX328.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMJB1/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMJB1/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMJB1/SI1408.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMJB1/SI778.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMJB1/SX148.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAR0/SX256.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAR0/SI1966.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAR0/SI1336.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAR0/SX346.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAR0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAR0/SX76.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAR0/SX436.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAR0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAR0/SX166.WAV
#   inflating: timit_dataset/TRAIN/DR3/MMAR0/SI706.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDNS0/SX381.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDNS0/SX21.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDNS0/SI1011.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDNS0/SI2271.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDNS0/SX111.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDNS0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDNS0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDNS0/SI873.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDNS0/SX291.WAV
#   inflating: timit_dataset/TRAIN/DR3/MDNS0/SX201.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSJW0/SX253.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSJW0/SX163.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSJW0/SX73.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSJW0/SI1333.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSJW0/SX343.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSJW0/SI1963.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSJW0/SI703.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSJW0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSJW0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/FSJW0/SX433.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJKR0/SI571.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJKR0/SX211.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJKR0/SX121.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJKR0/SX301.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJKR0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJKR0/SX391.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJKR0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJKR0/SI1201.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJKR0/SI1831.WAV
#   inflating: timit_dataset/TRAIN/DR3/MJKR0/SX31.WAV
#    creating: timit_dataset/TRAIN/DR8/FBCG1/
#    creating: timit_dataset/TRAIN/DR8/FCEG0/
#    creating: timit_dataset/TRAIN/DR8/FCLT0/
#    creating: timit_dataset/TRAIN/DR8/FJRB0/
#    creating: timit_dataset/TRAIN/DR8/FKLH0/
#    creating: timit_dataset/TRAIN/DR8/FMBG0/
#    creating: timit_dataset/TRAIN/DR8/FNKL0/
#    creating: timit_dataset/TRAIN/DR8/FPLS0/
#    creating: timit_dataset/TRAIN/DR8/MBCG0/
#    creating: timit_dataset/TRAIN/DR8/MBSB0/
#    creating: timit_dataset/TRAIN/DR8/MCXM0/
#    creating: timit_dataset/TRAIN/DR8/MEJS0/
#    creating: timit_dataset/TRAIN/DR8/MKDD0/
#    creating: timit_dataset/TRAIN/DR8/MKRG0/
#    creating: timit_dataset/TRAIN/DR8/MMEA0/
#    creating: timit_dataset/TRAIN/DR8/MMLM0/
#    creating: timit_dataset/TRAIN/DR8/MMPM0/
#    creating: timit_dataset/TRAIN/DR8/MMWS0/
#    creating: timit_dataset/TRAIN/DR8/MRDM0/
#    creating: timit_dataset/TRAIN/DR8/MRLK0/
#    creating: timit_dataset/TRAIN/DR8/MRRE0/
#    creating: timit_dataset/TRAIN/DR8/MTCS0/
#   inflating: timit_dataset/TRAIN/DR8/MEJS0/SI610.WAV
#   inflating: timit_dataset/TRAIN/DR8/MEJS0/SX160.WAV
#   inflating: timit_dataset/TRAIN/DR8/MEJS0/SX430.WAV
#   inflating: timit_dataset/TRAIN/DR8/MEJS0/SX340.WAV
#   inflating: timit_dataset/TRAIN/DR8/MEJS0/SI1870.WAV
#   inflating: timit_dataset/TRAIN/DR8/MEJS0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MEJS0/SI1240.WAV
#   inflating: timit_dataset/TRAIN/DR8/MEJS0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MEJS0/SX250.WAV
#   inflating: timit_dataset/TRAIN/DR8/MEJS0/SX70.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBSB0/SI723.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBSB0/SX183.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBSB0/SX363.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBSB0/SI1983.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBSB0/SX273.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBSB0/SX93.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBSB0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBSB0/SI1353.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBSB0/SX3.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBSB0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/FJRB0/SX132.WAV
#   inflating: timit_dataset/TRAIN/DR8/FJRB0/SX42.WAV
#   inflating: timit_dataset/TRAIN/DR8/FJRB0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/FJRB0/SX402.WAV
#   inflating: timit_dataset/TRAIN/DR8/FJRB0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/FJRB0/SI1302.WAV
#   inflating: timit_dataset/TRAIN/DR8/FJRB0/SI1932.WAV
#   inflating: timit_dataset/TRAIN/DR8/FJRB0/SX222.WAV
#   inflating: timit_dataset/TRAIN/DR8/FJRB0/SX312.WAV
#   inflating: timit_dataset/TRAIN/DR8/FJRB0/SI672.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SI1468.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX213.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SI843.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX303.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX393.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX33.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SX123.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRLK0/SI2140.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMEA0/SI2018.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMEA0/SX308.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMEA0/SX38.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMEA0/SI1388.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMEA0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMEA0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMEA0/SX128.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMEA0/SX398.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMEA0/SI758.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMEA0/SX218.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKDD0/SX37.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKDD0/SI2197.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKDD0/SI1567.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKDD0/SX217.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKDD0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKDD0/SX307.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKDD0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKDD0/SI937.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKDD0/SX127.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKDD0/SX397.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRRE0/SX74.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRRE0/SX344.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRRE0/SI1334.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRRE0/SX254.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRRE0/SX164.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRRE0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRRE0/SI952.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRRE0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRRE0/SI704.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRRE0/SX434.WAV
#   inflating: timit_dataset/TRAIN/DR8/FPLS0/SI1590.WAV
#   inflating: timit_dataset/TRAIN/DR8/FPLS0/SX150.WAV
#   inflating: timit_dataset/TRAIN/DR8/FPLS0/SX240.WAV
#   inflating: timit_dataset/TRAIN/DR8/FPLS0/SX60.WAV
#   inflating: timit_dataset/TRAIN/DR8/FPLS0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/FPLS0/SI960.WAV
#   inflating: timit_dataset/TRAIN/DR8/FPLS0/SX3.WAV
#   inflating: timit_dataset/TRAIN/DR8/FPLS0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/FPLS0/SI2220.WAV
#   inflating: timit_dataset/TRAIN/DR8/FPLS0/SX330.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMPM0/SX341.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMPM0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMPM0/SX161.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMPM0/SX251.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMPM0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMPM0/SI1691.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMPM0/SI2321.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMPM0/SX71.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMPM0/SI1061.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMPM0/SX431.WAV
#   inflating: timit_dataset/TRAIN/DR8/FKLH0/SI627.WAV
#   inflating: timit_dataset/TRAIN/DR8/FKLH0/SX267.WAV
#   inflating: timit_dataset/TRAIN/DR8/FKLH0/SI1257.WAV
#   inflating: timit_dataset/TRAIN/DR8/FKLH0/SI1887.WAV
#   inflating: timit_dataset/TRAIN/DR8/FKLH0/SX357.WAV
#   inflating: timit_dataset/TRAIN/DR8/FKLH0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/FKLH0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/FKLH0/SX447.WAV
#   inflating: timit_dataset/TRAIN/DR8/FKLH0/SX87.WAV
#   inflating: timit_dataset/TRAIN/DR8/FKLH0/SX177.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBCG0/SX57.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBCG0/SX327.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBCG0/SI957.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBCG0/SI486.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBCG0/SX417.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBCG0/SX237.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBCG0/SI2217.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBCG0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBCG0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MBCG0/SX147.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMLM0/SI2150.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMLM0/SI1527.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMLM0/SX267.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMLM0/SX357.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMLM0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMLM0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMLM0/SX447.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMLM0/SI897.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMLM0/SX87.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMLM0/SX177.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI861.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX51.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX411.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX141.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX231.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI2121.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SI1491.WAV
#   inflating: timit_dataset/TRAIN/DR8/MKRG0/SX31.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCEG0/SX78.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCEG0/SI618.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCEG0/SX348.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCEG0/SX438.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCEG0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCEG0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCEG0/SX168.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCEG0/SX258.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCEG0/SI1878.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCEG0/SI1248.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCLT0/SI2068.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCLT0/SX88.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCLT0/SX448.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCLT0/SI1438.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCLT0/SX178.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCLT0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCLT0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCLT0/SI808.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCLT0/SX268.WAV
#   inflating: timit_dataset/TRAIN/DR8/FCLT0/SX358.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI1595.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX335.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX65.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX155.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI1044.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX245.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SI965.WAV
#   inflating: timit_dataset/TRAIN/DR8/MRDM0/SX425.WAV
#   inflating: timit_dataset/TRAIN/DR8/FNKL0/SI1522.WAV
#   inflating: timit_dataset/TRAIN/DR8/FNKL0/SX196.WAV
#   inflating: timit_dataset/TRAIN/DR8/FNKL0/SI892.WAV
#   inflating: timit_dataset/TRAIN/DR8/FNKL0/SX442.WAV
#   inflating: timit_dataset/TRAIN/DR8/FNKL0/SX82.WAV
#   inflating: timit_dataset/TRAIN/DR8/FNKL0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/FNKL0/SI2152.WAV
#   inflating: timit_dataset/TRAIN/DR8/FNKL0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/FNKL0/SX262.WAV
#   inflating: timit_dataset/TRAIN/DR8/FNKL0/SX172.WAV
#   inflating: timit_dataset/TRAIN/DR8/MCXM0/SX361.WAV
#   inflating: timit_dataset/TRAIN/DR8/MCXM0/SX91.WAV
#   inflating: timit_dataset/TRAIN/DR8/MCXM0/SI1981.WAV
#   inflating: timit_dataset/TRAIN/DR8/MCXM0/SI1351.WAV
#   inflating: timit_dataset/TRAIN/DR8/MCXM0/SX181.WAV
#   inflating: timit_dataset/TRAIN/DR8/MCXM0/SI721.WAV
#   inflating: timit_dataset/TRAIN/DR8/MCXM0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MCXM0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MCXM0/SX271.WAV
#   inflating: timit_dataset/TRAIN/DR8/MCXM0/SX451.WAV
#   inflating: timit_dataset/TRAIN/DR8/FMBG0/SI2264.WAV
#   inflating: timit_dataset/TRAIN/DR8/FMBG0/SX440.WAV
#   inflating: timit_dataset/TRAIN/DR8/FMBG0/SX350.WAV
#   inflating: timit_dataset/TRAIN/DR8/FMBG0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/FMBG0/SI1790.WAV
#   inflating: timit_dataset/TRAIN/DR8/FMBG0/SX3.WAV
#   inflating: timit_dataset/TRAIN/DR8/FMBG0/SX80.WAV
#   inflating: timit_dataset/TRAIN/DR8/FMBG0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/FMBG0/SX260.WAV
#   inflating: timit_dataset/TRAIN/DR8/FMBG0/SI1160.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMWS0/SX78.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMWS0/SI559.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMWS0/SX348.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMWS0/SX438.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMWS0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMWS0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMWS0/SI1518.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMWS0/SX168.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMWS0/SX258.WAV
#   inflating: timit_dataset/TRAIN/DR8/MMWS0/SI888.WAV
#    creating: timit_dataset/TRAIN/DR7/FBLV0/
#    creating: timit_dataset/TRAIN/DR7/FCJS0/
#    creating: timit_dataset/TRAIN/DR7/FCRZ0/
#    creating: timit_dataset/TRAIN/DR7/FJEN0/
#    creating: timit_dataset/TRAIN/DR7/FJHK0/
#    creating: timit_dataset/TRAIN/DR7/FJRP1/
#    creating: timit_dataset/TRAIN/DR7/FJSK0/
#    creating: timit_dataset/TRAIN/DR7/FKDE0/
#    creating: timit_dataset/TRAIN/DR7/FKSR0/
#    creating: timit_dataset/TRAIN/DR7/FLEH0/
#    creating: timit_dataset/TRAIN/DR7/FLET0/
#    creating: timit_dataset/TRAIN/DR7/FMAH1/
#    creating: timit_dataset/TRAIN/DR7/FMKC0/
#    creating: timit_dataset/TRAIN/DR7/FPAB1/
#    creating: timit_dataset/TRAIN/DR7/FPAC0/
#    creating: timit_dataset/TRAIN/DR7/FREH0/
#    creating: timit_dataset/TRAIN/DR7/FSPM0/
#    creating: timit_dataset/TRAIN/DR7/FVKB0/
#    creating: timit_dataset/TRAIN/DR7/MADD0/
#    creating: timit_dataset/TRAIN/DR7/MAEO0/
#    creating: timit_dataset/TRAIN/DR7/MAFM0/
#    creating: timit_dataset/TRAIN/DR7/MBAR0/
#    creating: timit_dataset/TRAIN/DR7/MBBR0/
#    creating: timit_dataset/TRAIN/DR7/MBML0/
#    creating: timit_dataset/TRAIN/DR7/MBOM0/
#    creating: timit_dataset/TRAIN/DR7/MBTH0/
#    creating: timit_dataset/TRAIN/DR7/MCLK0/
#    creating: timit_dataset/TRAIN/DR7/MCRE0/
#    creating: timit_dataset/TRAIN/DR7/MCTH0/
#    creating: timit_dataset/TRAIN/DR7/MDCM0/
#    creating: timit_dataset/TRAIN/DR7/MDED0/
#    creating: timit_dataset/TRAIN/DR7/MDKS0/
#    creating: timit_dataset/TRAIN/DR7/MDLC1/
#    creating: timit_dataset/TRAIN/DR7/MDLM0/
#    creating: timit_dataset/TRAIN/DR7/MDLR0/
#    creating: timit_dataset/TRAIN/DR7/MDLR1/
#    creating: timit_dataset/TRAIN/DR7/MDPB0/
#    creating: timit_dataset/TRAIN/DR7/MFXS0/
#    creating: timit_dataset/TRAIN/DR7/MFXV0/
#    creating: timit_dataset/TRAIN/DR7/MGAK0/
#    creating: timit_dataset/TRAIN/DR7/MGAR0/
#    creating: timit_dataset/TRAIN/DR7/MGAW0/
#    creating: timit_dataset/TRAIN/DR7/MGSL0/
#    creating: timit_dataset/TRAIN/DR7/MHBS0/
#    creating: timit_dataset/TRAIN/DR7/MHXL0/
#    creating: timit_dataset/TRAIN/DR7/MJAI0/
#    creating: timit_dataset/TRAIN/DR7/MJDG0/
#    creating: timit_dataset/TRAIN/DR7/MJFR0/
#    creating: timit_dataset/TRAIN/DR7/MJJM0/
#    creating: timit_dataset/TRAIN/DR7/MJRA0/
#    creating: timit_dataset/TRAIN/DR7/MKAG0/
#    creating: timit_dataset/TRAIN/DR7/MKDB0/
#    creating: timit_dataset/TRAIN/DR7/MKLR0/
#    creating: timit_dataset/TRAIN/DR7/MMDG0/
#    creating: timit_dataset/TRAIN/DR7/MMWS1/
#    creating: timit_dataset/TRAIN/DR7/MNTW0/
#    creating: timit_dataset/TRAIN/DR7/MPAR0/
#    creating: timit_dataset/TRAIN/DR7/MPFU0/
#    creating: timit_dataset/TRAIN/DR7/MREM0/
#    creating: timit_dataset/TRAIN/DR7/MRLJ1/
#    creating: timit_dataset/TRAIN/DR7/MRMG0/
#    creating: timit_dataset/TRAIN/DR7/MRMH0/
#    creating: timit_dataset/TRAIN/DR7/MRPC1/
#    creating: timit_dataset/TRAIN/DR7/MSAH1/
#    creating: timit_dataset/TRAIN/DR7/MSDB0/
#    creating: timit_dataset/TRAIN/DR7/MSES0/
#    creating: timit_dataset/TRAIN/DR7/MTAB0/
#    creating: timit_dataset/TRAIN/DR7/MTER0/
#    creating: timit_dataset/TRAIN/DR7/MTKD0/
#    creating: timit_dataset/TRAIN/DR7/MTLC0/
#    creating: timit_dataset/TRAIN/DR7/MTML0/
#    creating: timit_dataset/TRAIN/DR7/MTMN0/
#    creating: timit_dataset/TRAIN/DR7/MTPR0/
#    creating: timit_dataset/TRAIN/DR7/MTWH1/
#    creating: timit_dataset/TRAIN/DR7/MVRW0/
#    creating: timit_dataset/TRAIN/DR7/MWRE0/
#    creating: timit_dataset/TRAIN/DR7/MWRP0/
#   inflating: timit_dataset/TRAIN/DR7/MADD0/SX88.WAV
#   inflating: timit_dataset/TRAIN/DR7/MADD0/SX448.WAV
#   inflating: timit_dataset/TRAIN/DR7/MADD0/SX178.WAV
#   inflating: timit_dataset/TRAIN/DR7/MADD0/SI1295.WAV
#   inflating: timit_dataset/TRAIN/DR7/MADD0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR7/MADD0/SI1798.WAV
#   inflating: timit_dataset/TRAIN/DR7/MADD0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR7/MADD0/SI538.WAV
#   inflating: timit_dataset/TRAIN/DR7/MADD0/SX268.WAV
#   inflating: timit_dataset/TRAIN/DR7/MADD0/SX358.WAV
#   inflating: timit_dataset/TRAIN/DR7/MDPB0/SI2126.WAV
#   inflating: timit_dataset/TRAIN/DR7/MDPB0/SX416.WAV
#   inflating: timit_dataset/TRAIN/DR7/MDPB0/SX326.WAV
#   inflating: timit_dataset/TRAIN/DR7/MDPB0/SX236.WAV
#   inflating: timit_dataset/TRAIN/DR7/MDPB0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR7/MDPB0/SI1760.WAV
#   inflating: timit_dataset/TRAIN/DR7/MDPB0/SI866.WAV
#   inflating: timit_dataset/TRAIN/DR7/MDPB0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR7/MDPB0/SX146.WAV
#   inflating: timit_dataset/TRAIN/DR7/MDPB0/SX56.WAV
#   inflating: timit_dataset/TRAIN/DR7/MGSL0/SX444.WAV
#   inflating: timit_dataset/TRAIN/DR7/MGSL0/SI534.WAV
#   inflating: timit_dataset/TRAIN/DR7/MGSL0/SI1164.WAV
#   inflating: timit_dataset/TRAIN/DR7/MGSL0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR7/MGSL0/SI797.WAV
#   inflating: timit_dataset/TRAIN/DR7/MGSL0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR7/MGSL0/SX264.WAV
#   inflating: timit_dataset/TRAIN/DR7/MGSL0/SX354.WAV
#   inflating: timit_dataset/TRAIN/DR7/MGSL0/SX84.WAV
#   inflating: timit_dataset/TRAIN/DR7/MGSL0/SX174.WAV
#   inflating: timit_dataset/TRAIN/DR7/MKAG0/SX30.WAV
#   inflating: timit_dataset/TRAIN/DR7/MKAG0/SI2239.WAV
#   inflating: timit_dataset/TRAIN/DR7/MKAG0/SX439.WAV
#   inflating: timit_dataset/TRAIN/DR7/MKAG0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR7/MKAG0/SX169.WAV
#   inflating: timit_dataset/TRAIN/DR7/MKAG0/SI979.WAV
#   inflating: timit_dataset/TRAIN/DR7/MKAG0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR7/MKAG0/SX259.WAV
#   inflating: timit_dataset/TRAIN/DR7/MKAG0/SI1609.WAV
#   inflating: timit_dataset/TRAIN/DR7/MKAG0/SX79.WAV
#   inflating: timit_dataset/TRAIN/DR7/MJRA0/SX426.WAV
#   inflating: timit_dataset/TRAIN/DR7/MJRA0/SX156.WAV
#   inflating: timit_dataset/TRAIN/DR7/MJRA0/SX246.WAV
#   inflating: timit_dataset/TRAIN/DR7/MJRA0/SX336.WAV
#   inflating: timit_dataset/TRAIN/DR7/MJRA0/SA1.WAV
#   inflating: timit_dataset/TRAIN/DR7/MJRA0/SA2.WAV
#   inflating: timit_dataset/TRAIN/DR7/MJRA0/SI1866.WAV
#   inflating: timit_dataset/TRAIN/DR7/MJRA0/SX66.WAV
# ...
#    creating: timit_dataset/TEST/DR5/FJCS0/
#    creating: timit_dataset/TEST/DR5/FJSA0/
#    creating: timit_dataset/TEST/DR5/FMAH0/
#    creating: timit_dataset/TEST/DR5/FNLP0/
#    creating: timit_dataset/TEST/DR5/FUTB0/
#    creating: timit_dataset/TEST/DR5/MAHH0/
#    creating: timit_dataset/TEST/DR5/MBPM0/
#    creating: timit_dataset/TEST/DR5/MCMB0/
#    creating: timit_dataset/TEST/DR5/MCRC0/
#    creating: timit_dataset/TEST/DR5/MCTT0/
#    creating: timit_dataset/TEST/DR5/MDAC2/
#    creating: timit_dataset/TEST/DR5/MDRB0/
#    creating: timit_dataset/TEST/DR5/MDWA0/
#    creating: timit_dataset/TEST/DR5/MDWK0/
#    creating: timit_dataset/TEST/DR5/MFGK0/
#    creating: timit_dataset/TEST/DR5/MKLT0/
#    creating: timit_dataset/TEST/DR5/MLIH0/
#    creating: timit_dataset/TEST/DR5/MRJM3/
#    creating: timit_dataset/TEST/DR5/MRPP0/
#    creating: timit_dataset/TEST/DR5/MRRK0/
#    creating: timit_dataset/TEST/DR5/MRWS1/
#    creating: timit_dataset/TEST/DR5/MSFH1/
#   inflating: timit_dataset/TEST/DR5/MKLT0/SX43.WAV
#   inflating: timit_dataset/TEST/DR5/MKLT0/SI1213.WAV
#   inflating: timit_dataset/TEST/DR5/MKLT0/SI1843.WAV
#   inflating: timit_dataset/TEST/DR5/MKLT0/SX133.WAV
#   inflating: timit_dataset/TEST/DR5/MKLT0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MKLT0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MKLT0/SX313.WAV
#   inflating: timit_dataset/TEST/DR5/MKLT0/SX223.WAV
#   inflating: timit_dataset/TEST/DR5/MKLT0/SX403.WAV
#   inflating: timit_dataset/TEST/DR5/MKLT0/SI583.WAV
#   inflating: timit_dataset/TEST/DR5/MRJM3/SX278.WAV
#   inflating: timit_dataset/TEST/DR5/MRJM3/SX368.WAV
#   inflating: timit_dataset/TEST/DR5/MRJM3/SX188.WAV
#   inflating: timit_dataset/TEST/DR5/MRJM3/SX98.WAV
#   inflating: timit_dataset/TEST/DR5/MRJM3/SX8.WAV
#   inflating: timit_dataset/TEST/DR5/MRJM3/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MRJM3/SI1448.WAV
#   inflating: timit_dataset/TEST/DR5/MRJM3/SI2078.WAV
#   inflating: timit_dataset/TEST/DR5/MRJM3/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MRJM3/SI1809.WAV
#   inflating: timit_dataset/TEST/DR5/MCRC0/SX102.WAV
#   inflating: timit_dataset/TEST/DR5/MCRC0/SI1092.WAV
#   inflating: timit_dataset/TEST/DR5/MCRC0/SX192.WAV
#   inflating: timit_dataset/TEST/DR5/MCRC0/SX12.WAV
#   inflating: timit_dataset/TEST/DR5/MCRC0/SI462.WAV
#   inflating: timit_dataset/TEST/DR5/MCRC0/SX372.WAV
#   inflating: timit_dataset/TEST/DR5/MCRC0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MCRC0/SI1722.WAV
#   inflating: timit_dataset/TEST/DR5/MCRC0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MCRC0/SX282.WAV
#   inflating: timit_dataset/TEST/DR5/MCMB0/SX278.WAV
#   inflating: timit_dataset/TEST/DR5/MCMB0/SI638.WAV
#   inflating: timit_dataset/TEST/DR5/MCMB0/SX368.WAV
#   inflating: timit_dataset/TEST/DR5/MCMB0/SX188.WAV
#   inflating: timit_dataset/TEST/DR5/MCMB0/SX98.WAV
#   inflating: timit_dataset/TEST/DR5/MCMB0/SX8.WAV
#   inflating: timit_dataset/TEST/DR5/MCMB0/SI1898.WAV
#   inflating: timit_dataset/TEST/DR5/MCMB0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MCMB0/SI1268.WAV
#   inflating: timit_dataset/TEST/DR5/MCMB0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MRRK0/SX28.WAV
#   inflating: timit_dataset/TEST/DR5/MRRK0/SX298.WAV
#   inflating: timit_dataset/TEST/DR5/MRRK0/SI1288.WAV
#   inflating: timit_dataset/TEST/DR5/MRRK0/SX388.WAV
#   inflating: timit_dataset/TEST/DR5/MRRK0/SI1716.WAV
#   inflating: timit_dataset/TEST/DR5/MRRK0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MRRK0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MRRK0/SI1918.WAV
#   inflating: timit_dataset/TEST/DR5/MRRK0/SX118.WAV
#   inflating: timit_dataset/TEST/DR5/MRRK0/SX208.WAV
#   inflating: timit_dataset/TEST/DR5/MLIH0/SX103.WAV
#   inflating: timit_dataset/TEST/DR5/MLIH0/SI1183.WAV
#   inflating: timit_dataset/TEST/DR5/MLIH0/SX193.WAV
#   inflating: timit_dataset/TEST/DR5/MLIH0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MLIH0/SI553.WAV
#   inflating: timit_dataset/TEST/DR5/MLIH0/SX13.WAV
#   inflating: timit_dataset/TEST/DR5/MLIH0/SX283.WAV
#   inflating: timit_dataset/TEST/DR5/MLIH0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MLIH0/SX373.WAV
#   inflating: timit_dataset/TEST/DR5/MLIH0/SI1813.WAV
#   inflating: timit_dataset/TEST/DR5/FJSA0/SI2009.WAV
#   inflating: timit_dataset/TEST/DR5/FJSA0/SX119.WAV
#   inflating: timit_dataset/TEST/DR5/FJSA0/SX389.WAV
#   inflating: timit_dataset/TEST/DR5/FJSA0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FJSA0/SI749.WAV
#   inflating: timit_dataset/TEST/DR5/FJSA0/SX299.WAV
#   inflating: timit_dataset/TEST/DR5/FJSA0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FJSA0/SI1379.WAV
#   inflating: timit_dataset/TEST/DR5/FJSA0/SX29.WAV
#   inflating: timit_dataset/TEST/DR5/FJSA0/SX209.WAV
#   inflating: timit_dataset/TEST/DR5/MFGK0/SI1744.WAV
#   inflating: timit_dataset/TEST/DR5/MFGK0/SX34.WAV
#   inflating: timit_dataset/TEST/DR5/MFGK0/SX124.WAV
#   inflating: timit_dataset/TEST/DR5/MFGK0/SX304.WAV
#   inflating: timit_dataset/TEST/DR5/MFGK0/SX214.WAV
#   inflating: timit_dataset/TEST/DR5/MFGK0/SI484.WAV
#   inflating: timit_dataset/TEST/DR5/MFGK0/SI1451.WAV
#   inflating: timit_dataset/TEST/DR5/MFGK0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MFGK0/SX394.WAV
#   inflating: timit_dataset/TEST/DR5/MFGK0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FGMD0/SX323.WAV
#   inflating: timit_dataset/TEST/DR5/FGMD0/SI1943.WAV
#   inflating: timit_dataset/TEST/DR5/FGMD0/SX413.WAV
#   inflating: timit_dataset/TEST/DR5/FGMD0/SX53.WAV
#   inflating: timit_dataset/TEST/DR5/FGMD0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FGMD0/SI2107.WAV
#   inflating: timit_dataset/TEST/DR5/FGMD0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FGMD0/SX143.WAV
#   inflating: timit_dataset/TEST/DR5/FGMD0/SI683.WAV
#   inflating: timit_dataset/TEST/DR5/FGMD0/SX233.WAV
#   inflating: timit_dataset/TEST/DR5/MDAC2/SI560.WAV
#   inflating: timit_dataset/TEST/DR5/MDAC2/SX279.WAV
#   inflating: timit_dataset/TEST/DR5/MDAC2/SX189.WAV
#   inflating: timit_dataset/TEST/DR5/MDAC2/SX369.WAV
#   inflating: timit_dataset/TEST/DR5/MDAC2/SX99.WAV
#   inflating: timit_dataset/TEST/DR5/MDAC2/SX9.WAV
#   inflating: timit_dataset/TEST/DR5/MDAC2/SI2259.WAV
#   inflating: timit_dataset/TEST/DR5/MDAC2/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MDAC2/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MDAC2/SI999.WAV
#   inflating: timit_dataset/TEST/DR5/FAWF0/SX10.WAV
#   inflating: timit_dataset/TEST/DR5/FAWF0/SX280.WAV
#   inflating: timit_dataset/TEST/DR5/FAWF0/SI2260.WAV
#   inflating: timit_dataset/TEST/DR5/FAWF0/SX370.WAV
#   inflating: timit_dataset/TEST/DR5/FAWF0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FAWF0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FAWF0/SX100.WAV
#   inflating: timit_dataset/TEST/DR5/FAWF0/SX190.WAV
#   inflating: timit_dataset/TEST/DR5/FAWF0/SI1000.WAV
#   inflating: timit_dataset/TEST/DR5/FAWF0/SI1630.WAV
#   inflating: timit_dataset/TEST/DR5/FASW0/SX200.WAV
#   inflating: timit_dataset/TEST/DR5/FASW0/SI2180.WAV
#   inflating: timit_dataset/TEST/DR5/FASW0/SI1550.WAV
#   inflating: timit_dataset/TEST/DR5/FASW0/SX110.WAV
#   inflating: timit_dataset/TEST/DR5/FASW0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FASW0/SX380.WAV
#   inflating: timit_dataset/TEST/DR5/FASW0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FASW0/SX290.WAV
#   inflating: timit_dataset/TEST/DR5/FASW0/SX20.WAV
#   inflating: timit_dataset/TEST/DR5/FASW0/SI920.WAV
#   inflating: timit_dataset/TEST/DR5/MRWS1/SX410.WAV
#   inflating: timit_dataset/TEST/DR5/MRWS1/SI1130.WAV
#   inflating: timit_dataset/TEST/DR5/MRWS1/SX140.WAV
#   inflating: timit_dataset/TEST/DR5/MRWS1/SI1496.WAV
#   inflating: timit_dataset/TEST/DR5/MRWS1/SX320.WAV
#   inflating: timit_dataset/TEST/DR5/MRWS1/SX230.WAV
#   inflating: timit_dataset/TEST/DR5/MRWS1/SX50.WAV
#   inflating: timit_dataset/TEST/DR5/MRWS1/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MRWS1/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MRWS1/SI500.WAV
#   inflating: timit_dataset/TEST/DR5/FHEW0/SX43.WAV
#   inflating: timit_dataset/TEST/DR5/FHEW0/SX133.WAV
#   inflating: timit_dataset/TEST/DR5/FHEW0/SI763.WAV
#   inflating: timit_dataset/TEST/DR5/FHEW0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FHEW0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FHEW0/SI690.WAV
#   inflating: timit_dataset/TEST/DR5/FHEW0/SX313.WAV
#   inflating: timit_dataset/TEST/DR5/FHEW0/SX223.WAV
#   inflating: timit_dataset/TEST/DR5/FHEW0/SI2023.WAV
#   inflating: timit_dataset/TEST/DR5/FHEW0/SX403.WAV
#   inflating: timit_dataset/TEST/DR5/MCTT0/SI1144.WAV
#   inflating: timit_dataset/TEST/DR5/MCTT0/SI2188.WAV
#   inflating: timit_dataset/TEST/DR5/MCTT0/SX28.WAV
#   inflating: timit_dataset/TEST/DR5/MCTT0/SX298.WAV
#   inflating: timit_dataset/TEST/DR5/MCTT0/SX388.WAV
#   inflating: timit_dataset/TEST/DR5/MCTT0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MCTT0/SI928.WAV
#   inflating: timit_dataset/TEST/DR5/MCTT0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MCTT0/SX118.WAV
#   inflating: timit_dataset/TEST/DR5/MCTT0/SX208.WAV
#   inflating: timit_dataset/TEST/DR5/FNLP0/SX228.WAV
#   inflating: timit_dataset/TEST/DR5/FNLP0/SI1308.WAV
#   inflating: timit_dataset/TEST/DR5/FNLP0/SX48.WAV
#   inflating: timit_dataset/TEST/DR5/FNLP0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FNLP0/SI1938.WAV
#   inflating: timit_dataset/TEST/DR5/FNLP0/SI678.WAV
#   inflating: timit_dataset/TEST/DR5/FNLP0/SX138.WAV
#   inflating: timit_dataset/TEST/DR5/FNLP0/SX408.WAV
#   inflating: timit_dataset/TEST/DR5/FNLP0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FNLP0/SX318.WAV
#   inflating: timit_dataset/TEST/DR5/FCAL1/SX323.WAV
#   inflating: timit_dataset/TEST/DR5/FCAL1/SX413.WAV
#   inflating: timit_dataset/TEST/DR5/FCAL1/SX53.WAV
#   inflating: timit_dataset/TEST/DR5/FCAL1/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FCAL1/SI2033.WAV
#   inflating: timit_dataset/TEST/DR5/FCAL1/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FCAL1/SX143.WAV
#   inflating: timit_dataset/TEST/DR5/FCAL1/SX233.WAV
#   inflating: timit_dataset/TEST/DR5/FCAL1/SI1403.WAV
#   inflating: timit_dataset/TEST/DR5/FCAL1/SI773.WAV
#   inflating: timit_dataset/TEST/DR5/MBPM0/SI1584.WAV
#   inflating: timit_dataset/TEST/DR5/MBPM0/SX227.WAV
#   inflating: timit_dataset/TEST/DR5/MBPM0/SX317.WAV
#   inflating: timit_dataset/TEST/DR5/MBPM0/SI1577.WAV
#   inflating: timit_dataset/TEST/DR5/MBPM0/SX47.WAV
#   inflating: timit_dataset/TEST/DR5/MBPM0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MBPM0/SX407.WAV
#   inflating: timit_dataset/TEST/DR5/MBPM0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MBPM0/SI947.WAV
#   inflating: timit_dataset/TEST/DR5/MBPM0/SX137.WAV
#   inflating: timit_dataset/TEST/DR5/FJCS0/SX319.WAV
#   inflating: timit_dataset/TEST/DR5/FJCS0/SX49.WAV
#   inflating: timit_dataset/TEST/DR5/FJCS0/SI1939.WAV
#   inflating: timit_dataset/TEST/DR5/FJCS0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FJCS0/SX409.WAV
#   inflating: timit_dataset/TEST/DR5/FJCS0/SI1833.WAV
#   inflating: timit_dataset/TEST/DR5/FJCS0/SX229.WAV
#   inflating: timit_dataset/TEST/DR5/FJCS0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FJCS0/SI1309.WAV
#   inflating: timit_dataset/TEST/DR5/FJCS0/SX139.WAV
#   inflating: timit_dataset/TEST/DR5/FHES0/SI1739.WAV
#   inflating: timit_dataset/TEST/DR5/FHES0/SX119.WAV
#   inflating: timit_dataset/TEST/DR5/FHES0/SX389.WAV
#   inflating: timit_dataset/TEST/DR5/FHES0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FHES0/SI1109.WAV
#   inflating: timit_dataset/TEST/DR5/FHES0/SX299.WAV
#   inflating: timit_dataset/TEST/DR5/FHES0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FHES0/SX29.WAV
#   inflating: timit_dataset/TEST/DR5/FHES0/SI479.WAV
#   inflating: timit_dataset/TEST/DR5/FHES0/SX209.WAV
#   inflating: timit_dataset/TEST/DR5/MDWK0/SX10.WAV
#   inflating: timit_dataset/TEST/DR5/MDWK0/SX280.WAV
#   inflating: timit_dataset/TEST/DR5/MDWK0/SI910.WAV
#   inflating: timit_dataset/TEST/DR5/MDWK0/SX370.WAV
#   inflating: timit_dataset/TEST/DR5/MDWK0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MDWK0/SI2170.WAV
#   inflating: timit_dataset/TEST/DR5/MDWK0/SI1540.WAV
#   inflating: timit_dataset/TEST/DR5/MDWK0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MDWK0/SX100.WAV
#   inflating: timit_dataset/TEST/DR5/MDWK0/SX190.WAV
#   inflating: timit_dataset/TEST/DR5/MDWA0/SX185.WAV
#   inflating: timit_dataset/TEST/DR5/MDWA0/SI1146.WAV
#   inflating: timit_dataset/TEST/DR5/MDWA0/SI519.WAV
#   inflating: timit_dataset/TEST/DR5/MDWA0/SX365.WAV
#   inflating: timit_dataset/TEST/DR5/MDWA0/SI1445.WAV
#   inflating: timit_dataset/TEST/DR5/MDWA0/SX5.WAV
#   inflating: timit_dataset/TEST/DR5/MDWA0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MDWA0/SX275.WAV
#   inflating: timit_dataset/TEST/DR5/MDWA0/SX95.WAV
#   inflating: timit_dataset/TEST/DR5/MDWA0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FUTB0/SX34.WAV
#   inflating: timit_dataset/TEST/DR5/FUTB0/SX124.WAV
#   inflating: timit_dataset/TEST/DR5/FUTB0/SX304.WAV
#   inflating: timit_dataset/TEST/DR5/FUTB0/SI1330.WAV
#   inflating: timit_dataset/TEST/DR5/FUTB0/SI1834.WAV
#   inflating: timit_dataset/TEST/DR5/FUTB0/SX214.WAV
#   inflating: timit_dataset/TEST/DR5/FUTB0/SI1204.WAV
#   inflating: timit_dataset/TEST/DR5/FUTB0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FUTB0/SX394.WAV
#   inflating: timit_dataset/TEST/DR5/FUTB0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MRPP0/SX14.WAV
#   inflating: timit_dataset/TEST/DR5/MRPP0/SX194.WAV
#   inflating: timit_dataset/TEST/DR5/MRPP0/SI1184.WAV
#   inflating: timit_dataset/TEST/DR5/MRPP0/SX104.WAV
#   inflating: timit_dataset/TEST/DR5/MRPP0/SI554.WAV
#   inflating: timit_dataset/TEST/DR5/MRPP0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MRPP0/SX284.WAV
#   inflating: timit_dataset/TEST/DR5/MRPP0/SX374.WAV
#   inflating: timit_dataset/TEST/DR5/MRPP0/SI1814.WAV
#   inflating: timit_dataset/TEST/DR5/MRPP0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MSFH1/SI1900.WAV
#   inflating: timit_dataset/TEST/DR5/MSFH1/SX10.WAV
#   inflating: timit_dataset/TEST/DR5/MSFH1/SX280.WAV
#   inflating: timit_dataset/TEST/DR5/MSFH1/SI640.WAV
#   inflating: timit_dataset/TEST/DR5/MSFH1/SX370.WAV
#   inflating: timit_dataset/TEST/DR5/MSFH1/SI1270.WAV
#   inflating: timit_dataset/TEST/DR5/MSFH1/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MSFH1/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MSFH1/SX100.WAV
#   inflating: timit_dataset/TEST/DR5/MSFH1/SX190.WAV
#   inflating: timit_dataset/TEST/DR5/MDRB0/SX274.WAV
#   inflating: timit_dataset/TEST/DR5/MDRB0/SI544.WAV
#   inflating: timit_dataset/TEST/DR5/MDRB0/SI1174.WAV
#   inflating: timit_dataset/TEST/DR5/MDRB0/SI2109.WAV
#   inflating: timit_dataset/TEST/DR5/MDRB0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MDRB0/SX4.WAV
#   inflating: timit_dataset/TEST/DR5/MDRB0/SX364.WAV
#   inflating: timit_dataset/TEST/DR5/MDRB0/SX94.WAV
#   inflating: timit_dataset/TEST/DR5/MDRB0/SX184.WAV
#   inflating: timit_dataset/TEST/DR5/MDRB0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/MAHH0/SI1294.WAV
#   inflating: timit_dataset/TEST/DR5/MAHH0/SX34.WAV
#   inflating: timit_dataset/TEST/DR5/MAHH0/SX124.WAV
#   inflating: timit_dataset/TEST/DR5/MAHH0/SX304.WAV
#   inflating: timit_dataset/TEST/DR5/MAHH0/SX214.WAV
#   inflating: timit_dataset/TEST/DR5/MAHH0/SI1924.WAV
#   inflating: timit_dataset/TEST/DR5/MAHH0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/MAHH0/SI664.WAV
#   inflating: timit_dataset/TEST/DR5/MAHH0/SX394.WAV
#   inflating: timit_dataset/TEST/DR5/MAHH0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FMAH0/SI1289.WAV
#   inflating: timit_dataset/TEST/DR5/FMAH0/SI659.WAV
#   inflating: timit_dataset/TEST/DR5/FMAH0/SX119.WAV
#   inflating: timit_dataset/TEST/DR5/FMAH0/SX389.WAV
#   inflating: timit_dataset/TEST/DR5/FMAH0/SA1.WAV
#   inflating: timit_dataset/TEST/DR5/FMAH0/SI1919.WAV
#   inflating: timit_dataset/TEST/DR5/FMAH0/SX299.WAV
#   inflating: timit_dataset/TEST/DR5/FMAH0/SA2.WAV
#   inflating: timit_dataset/TEST/DR5/FMAH0/SX29.WAV
#   inflating: timit_dataset/TEST/DR5/FMAH0/SX209.WAV

# %%
import os
import random
import time
import gc
import numpy as np
import pandas as pd
import torch
import torchaudio
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score
from transformers import Wav2Vec2Model, Wav2Vec2FeatureExtractor, logging
from tqdm.notebook import tqdm

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
logging.set_verbosity_error() # Suppress transformer warnings

# %%
train_df = pd.read_csv('/content/drive/MyDrive/sps/final_train_data_merged.csv')
test_df = pd.read_csv('/content/drive/MyDrive/sps/final_test_data_merged.csv')
print(f"Loaded train data: {len(train_df)} rows, test data: {len(test_df)} rows")
# Out:
# Loaded train data: 4490 rows, test data: 1640 rows

# %%
train_df.head()
# Out:
#    index  Use_x   DR SpeakerID   filename                   FilePath Gender  \
# 0      8  TRAIN  DR4     MMDM0  SI681.WAV  TRAIN/DR4/MMDM0/SI681.WAV      M
# 1     18  TRAIN  DR4     MMDM0    SA2.WAV    TRAIN/DR4/MMDM0/SA2.WAV      M
# 2     20  TRAIN  DR4     MMDM0  SX411.WAV  TRAIN/DR4/MMDM0/SX411.WAV      M
# 3     23  TRAIN  DR4     MMDM0    SA1.WAV    TRAIN/DR4/MMDM0/SA1.WAV      M
# 4     26  TRAIN  DR4     MMDM0  SX231.WAV  TRAIN/DR4/MMDM0/SX231.WAV      M
#
#   Ethnicity   age  height
# 0       WHT  27.2   190.5
# 1       WHT  27.2   190.5
# 2       WHT  27.2   190.5
# 3       WHT  27.2   190.5
# 4       WHT  27.2   190.5

# %%
test_df.head()
# Out:
#    index Use_x   DR SpeakerID   filename                  FilePath Gender  \
# 0      1  TEST  DR4     MGMM0  SX139.WAV  TEST/DR4/MGMM0/SX139.WAV      M
# 1     18  TEST  DR4     MGMM0    SA2.WAV    TEST/DR4/MGMM0/SA2.WAV      M
# 2     21  TEST  DR4     MGMM0  SX229.WAV  TEST/DR4/MGMM0/SX229.WAV      M
# 3     24  TEST  DR4     MGMM0    SA1.WAV    TEST/DR4/MGMM0/SA1.WAV      M
# 4     25  TEST  DR4     MGMM0   SX49.WAV   TEST/DR4/MGMM0/SX49.WAV      M
#
#   Ethnicity    age  height
# 0       WHT  23.43   177.8
# 1       WHT  23.43   177.8
# 2       WHT  23.43   177.8
# 3       WHT  23.43   177.8
# 4       WHT  23.43   177.8

# %%
train_df.drop(columns=['index','Use_x','DR'], inplace=True)
test_df.drop(columns=['index','Use_x','DR'], inplace=True)

# %%
class Config:
  # --- Paths ---
  AUDIO_ROOT_DIR = '/content/timit_dataset'
  CKPT_PATH     = './sps_model.pth'

  # --- Audio Processing ---
  SAMPLE_RATE   = 16000
  CLIP_SECONDS  = 4.0
  WAV_LEN       = int(SAMPLE_RATE * CLIP_SECONDS)

  # --- Model Architecture ---
  PRETRAINED_W2V2 = 'facebook/wav2vec2-base-960h'
  FREEZE_ENCODER = True
  LSTM_HIDDEN   = 256
  LSTM_LAYERS   = 3
  DROPOUT_RATE  = 0.3

  # --- Training ---
  DEVICE        = 'cuda' if torch.cuda.is_available() else 'cpu'
  EPOCHS        = 50
  BATCH_SIZE    = 32
  LEARNING_RATE = 3e-5
  OPTIMIZER_WEIGHT_DECAY = 0.01
  USE_MIXED_PRECISION = False
  GRADIENT_CLIP_VAL = 1.0

  # --- Validation ---
  VAL_SPLIT_RATIO = 0.25
  VAL_SPLIT_SEED  = 42

  # --- Task Configuration  ---
  TASKS = { 'age': {'type': 'regression', 'loss_weight': 1.0},
            'Gender': {'type': 'classification', 'loss_weight': 1.0},
            'height': {'type': 'regression', 'loss_weight': 1.0}
          # 'Ethnicity': {'type': 'classification', 'loss_weight': 1.0}}
  }

  GENDER_MAP = {}
  # ETHNICITY_MAP = {}
  NORM_STATS = {'age': {'mean': 0.0, 'std': 1.0}, 'height': {'mean': 0.0, 'std': 1.0}}

  # --- DataLoader ---
  NUM_WORKERS   = 4 # Keep 1 or 2 to reduce RAM overhead
  PIN_MEMORY    = True # True if using GPU

# %%
cfg = Config()

# %%
random.seed(cfg.VAL_SPLIT_SEED)
np.random.seed(cfg.VAL_SPLIT_SEED)
torch.manual_seed(cfg.VAL_SPLIT_SEED)

if torch.cuda.is_available():
  torch.cuda.manual_seed_all(cfg.VAL_SPLIT_SEED)

# %%
required_cols_for_tasks = list(cfg.TASKS.keys()) + ['SpeakerID']
missing_cols = [col for col in required_cols_for_tasks if col not in train_df.columns]

if missing_cols:
  print(f"Missing required columns in train_df: {missing_cols}")

# %%
for task_name, task_info in cfg.TASKS.items():
  if task_info['type'] == 'regression':
    mean = train_df[task_name].mean()
    std = train_df[task_name].std()
    std = std if (np.isfinite(std) and std > 0) else 1.0 # Handle std=0 or NaN
    cfg.NORM_STATS[task_name]['mean'] = mean
    cfg.NORM_STATS[task_name]['std'] = std
    print(f"  {task_name.capitalize()} stats: Mean={mean:.2f}, Std={std:.2f}")


  elif task_info['type'] == 'classification':
    cats = train_df[task_name].astype(str).str.upper().unique()
    cats = sorted(list(cats)) # Sort for consistent mapping order
    mapping = {cat: i for i, cat in enumerate(cats)}
    num_classes = len(mapping)

    if task_name == 'Gender':
      cfg.GENDER_MAP = mapping
      print(f"Gender mapping: {cfg.GENDER_MAP}")
    # elif task_name == 'Ethnicity':
    #   cfg.ETHNICITY_MAP = mapping
    #   print(f" Ethnicity mapping: {cfg.ETHNICITY_MAP}")
    else:
      print(f"Warning: No specific map variable defined for classification task '{task_name}' in Config.")

    cfg.TASKS[task_name]['num_classes'] = num_classes
    if num_classes == 0:
      print(f"Warning: No unique categories found for '{task_name}' in training data!")
# Out:
#   Age stats: Mean=30.29, Std=7.77
# Gender mapping: {'F': 0, 'M': 1}
#   Height stats: Mean=175.75, Std=9.52

# %%
speaker_ids = train_df['SpeakerID'].unique()
train_spk_ids, val_spk_ids = train_test_split(
    speaker_ids,
    test_size=cfg.VAL_SPLIT_RATIO,
    random_state=cfg.VAL_SPLIT_SEED,
)

val_df = train_df[train_df['SpeakerID'].isin(val_spk_ids)].copy()
train_df = train_df[train_df['SpeakerID'].isin(train_spk_ids)].copy()
test_df = test_df.copy()

print(f"Data split: Train={len(train_df)} ({len(train_spk_ids)} spk), Val={len(val_df)} ({len(val_spk_ids)} spk), Test={len(test_df)} ({test_df['SpeakerID'].nunique()} spk)")
# Out:
# Data split: Train=3360 (336 spk), Val=1130 (113 spk), Test=1640 (164 spk)

# %%
print(f"train_df shape: {train_df.shape}")
print(f"val_df shape: {val_df.shape}")
print(f"test_df shape: {test_df.shape}")
# Out:
# train_df shape: (3360, 7)
# val_df shape: (1130, 7)
# test_df shape: (1640, 7)

# %%
# print("NaN entries in train_df:")
# print(train_df.isna().sum())
# print("\nNaN entries in val_df:")
# print(val_df.isna().sum())
# print("\nNaN entries in test_df:")
# print(test_df.isna().sum())

# %%
class PadCrop:
  def __init__(self, length, mode='train'):
    self.length = length
    self.mode = mode

  def __call__(self, wav):
    current_len = wav.shape[-1]
    if current_len == self.length:
      return wav
    elif current_len > self.length:
      start = random.randint(0, current_len - self.length) if self.mode == 'train' else (current_len - self.length) // 2
      wav = wav[..., start : start + self.length]
    else:
      pad_width = self.length - current_len
      pad_left = pad_width // 2
      pad_right = pad_width - pad_left
      wav = F.pad(wav, (pad_left, pad_right), mode='constant', value=0)
    return wav

# %%
class TimitDataset(Dataset):
  def __init__(self, data_df, cfg: Config, mode='train'):
    self.data_df = data_df.reset_index(drop=True)
    self.cfg = cfg
    self.mode = mode
    self.pad_crop = PadCrop(cfg.WAV_LEN, mode)
    self.target_cols = list(cfg.TASKS.keys())

    for col in self.target_cols + ['FilePath']:
        if col not in self.data_df.columns:
          print(f"Column '{col}' missing in DataFrame for mode '{mode}'.")

  def __len__(self):
    return len(self.data_df)

  def __getitem__(self, idx):
    if idx >= len(self.data_df):
      print("Index out of bounds")

    row = self.data_df.iloc[idx]
    wav_relative_path = row['FilePath']
    full_wav_path = os.path.normpath(os.path.join(self.cfg.AUDIO_ROOT_DIR, wav_relative_path))

    try:
      wav, sr = torchaudio.load(full_wav_path)
    except Exception as e:
      print(f"ERROR loading audio idx {idx}, path: {full_wav_path}. Error: {e}. Returning None.")
      return None

    if sr != self.cfg.SAMPLE_RATE:
      if not hasattr(self, f'resampler_{sr}'):
        setattr(self, f'resampler_{sr}', torchaudio.transforms.Resample(sr, self.cfg.SAMPLE_RATE))
      wav = getattr(self, f'resampler_{sr}')(wav)

    if wav.shape[0] > 1:
      wav = torch.mean(wav, dim=0, keepdim=True)
    wav = self.pad_crop(wav)
    wav = wav.squeeze(0)  # Remove channel dim -> (wav_len,)

    if torch.isnan(wav).any():
      print(f"CRITICAL NAN DETECTED in wav for item {idx}, path: {full_wav_path} BEFORE returning from dataset.")

    targets = {}
    for task_name, task_info in self.cfg.TASKS.items():
      value = row[task_name]
      if task_info['type'] == 'regression':
        mean = self.cfg.NORM_STATS[task_name]['mean']
        std = self.cfg.NORM_STATS[task_name]['std']
        norm_value = (value - mean) / std
        targets[task_name] = torch.tensor(norm_value, dtype=torch.float32)

      elif task_info['type'] == 'classification':
        value_upper = str(value).upper()
        # mapping = self.cfg.GENDER_MAP if task_name == 'Gender' else self.cfg.ETHNICITY_MAP
        if task_name == 'Gender':
          mapping = self.cfg.GENDER_MAP

        idx_value = mapping.get(value_upper, 0)  # Class 0 if unseen

        if value_upper not in mapping:
          print(f"Warning: Unmapped category '{value}' (upper: '{value_upper}') for task '{task_name}' at idx {idx}. Defaulting to 0.")
        targets[task_name] = torch.tensor(idx_value, dtype=torch.long)

    return wav, targets

# %%
def collate_fn(batch):  # Collate to handle None returns from dataset
  batch = [item for item in batch if item is not None]
  if not batch:
    return {}, {}

  wavs = [item[0] for item in batch]
  target_dicts = [item[1] for item in batch]
  padded_wavs = torch.nn.utils.rnn.pad_sequence(wavs, batch_first=True, padding_value=0.0)
  collated_targets = {key: torch.stack([d[key] for d in target_dicts]) for key in target_dicts[0].keys()}

  return padded_wavs, collated_targets

# %%
train_dataset = TimitDataset(train_df, cfg, mode='train')
val_dataset = TimitDataset(val_df, cfg, mode='eval')
test_dataset = TimitDataset(test_df, cfg, mode='eval')

train_loader = DataLoader(
    train_dataset, batch_size=cfg.BATCH_SIZE, shuffle=True,
    num_workers=cfg.NUM_WORKERS, pin_memory=cfg.PIN_MEMORY, drop_last=True, collate_fn=collate_fn
)
val_loader = DataLoader(
    val_dataset, batch_size=cfg.BATCH_SIZE, shuffle=False,
    num_workers=cfg.NUM_WORKERS, pin_memory=cfg.PIN_MEMORY, collate_fn=collate_fn
)
test_loader = DataLoader(
    test_dataset, batch_size=cfg.BATCH_SIZE, shuffle=False,
    num_workers=cfg.NUM_WORKERS, pin_memory=cfg.PIN_MEMORY, collate_fn=collate_fn
)

# %%
class spsBiLSTM(nn.Module):
  def __init__(self, cfg: Config):
    super().__init__()
    self.cfg = cfg

    # Wav2Vec2.0
    self.feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained(cfg.PRETRAINED_W2V2)
    self.encoder = Wav2Vec2Model.from_pretrained(cfg.PRETRAINED_W2V2)
    if cfg.FREEZE_ENCODER:
      for param in self.encoder.parameters(): param.requires_grad = False
    encoder_dim = self.encoder.config.hidden_size

    # LSTM layers
    self.lstm = nn.LSTM(
        input_size=encoder_dim, hidden_size=cfg.LSTM_HIDDEN, num_layers=cfg.LSTM_LAYERS,
        batch_first=True, bidirectional=True, dropout=cfg.DROPOUT_RATE if cfg.LSTM_LAYERS > 1 else 0
    )
    lstm_output_dim = cfg.LSTM_HIDDEN * 2

    # Prediction heads
    self.heads = nn.ModuleDict()
    head_input_dim = lstm_output_dim
    head_hidden_dim = head_input_dim // 2

    for task_name, task_info in cfg.TASKS.items():
      if task_info['type'] == 'regression':
        output_dim = 1

      elif task_info['type'] == 'classification':
          num_classes = task_info.get('num_classes')
          if num_classes is None or num_classes == 0:
            print(f"Num classes not set or is 0 for {task_name}")
          output_dim = num_classes
      else:
        print(f"Unknown task type: {task_info['type']}")

      self.heads[task_name] = nn.Sequential(
          nn.Linear(head_input_dim, head_hidden_dim),
          nn.ReLU(),
          nn.Dropout(cfg.DROPOUT_RATE),
          nn.Linear(head_hidden_dim, output_dim)
      )


  def forward(self, waveform):
    dev = next(self.parameters()).device

    if waveform.ndim == 2:      # (Batch, Seq_len)
      waveform_list = [wav.cpu().numpy() for wav in waveform]
    elif waveform.ndim == 1:    # (Seq_len) - for a batch size of 1, if collate_fn doesn't batch
      waveform_list = [waveform.cpu().numpy()]
    else:
      print(f"Unexpected waveform ndim: {waveform.ndim}")

    inputs = self.feature_extractor(
        waveform_list,
        sampling_rate=self.cfg.SAMPLE_RATE,
        return_tensors="pt",
        padding="longest",
        return_attention_mask=True
    )
    inputs = {k: v.to(dev) for k, v in inputs.items()}
    # if torch.isnan(inputs['input_values']).any():
    #   print("DEBUG NAN: NaNs found in 'input_values' AFTER Wav2Vec2FeatureExtractor!")

    attention_mask = inputs.get('attention_mask')
    if attention_mask is None:
      print("WARN: 'attention_mask' is None after feature_extractor. Creating default (all ones).")
      attention_mask = torch.ones_like(inputs['input_values'], device=dev, dtype=torch.long)

    hidden_states = self.encoder(inputs['input_values'], attention_mask=attention_mask).last_hidden_state
    # print(f"DEBUG STATS: hidden_states - Min: {hidden_states.min().item()}, Max: {hidden_states.max().item()}, Mean: {hidden_states.mean().item()}, Std: {hidden_states.std().item()}")
    # if torch.isnan(hidden_states).any() or torch.isinf(hidden_states).any():
    #   print("CRITICAL DEBUG: NaNs or Infs found in 'hidden_states' (input to LSTM)!")

    # if torch.isnan(inputs['input_values']).any():
    #   print("DEBUG NAN: NaNs found in 'input_values' AFTER Wav2Vec2FeatureExtractor!")

    lstm_output, _ = self.lstm(hidden_states)
    # if torch.isnan(lstm_output).any():
    #   print("DEBUG NAN: NaNs found in 'lstm_output' AFTER LSTM!")

    # mask = inputs['attention_mask'].unsqueeze(-1).repeat(1, 1, lstm_output.shape[-1])
    mask = (lstm_output != 0).type(torch.float32)

    pooled = torch.sum(lstm_output * mask, dim=1) / mask.sum(dim=1).clamp(min=1e-6)
    # if torch.isnan(pooled).any():
    #   print("DEBUG NAN: NaNs found in 'pooled' output!")

    preds = {name: head(pooled).squeeze(-1) if self.cfg.TASKS[name]['type'] == 'regression' else head(pooled) for name, head in self.heads.items()}
    return preds

# %%
model = spsBiLSTM(cfg).to(cfg.DEVICE)
# print(model)
# Out:
# preprocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.60k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]

# %%
optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=cfg.LEARNING_RATE, weight_decay=cfg.OPTIMIZER_WEIGHT_DECAY
)
print(f"Optimizer: AdamW (LR={cfg.LEARNING_RATE}, WD={cfg.OPTIMIZER_WEIGHT_DECAY})")

criterion_reg = nn.MSELoss()
criterion_cls = nn.CrossEntropyLoss()

scaler = torch.cuda.amp.GradScaler() if cfg.USE_MIXED_PRECISION and cfg.DEVICE == 'cuda' else None
if scaler:
  print("Using Mixed Precision training.")
# Out:
# Optimizer: AdamW (LR=3e-05, WD=0.01)

# %%
start_epoch = 1
best_val_metric = float('inf')

# %%
if os.path.isfile(cfg.CKPT_PATH):
  print(f"Loading checkpoint: {cfg.CKPT_PATH}")

  try:
    checkpoint = torch.load(cfg.CKPT_PATH, map_location=cfg.DEVICE)
    if 'model_state_dict' in checkpoint:
      model.load_state_dict(checkpoint['model_state_dict'], strict=False) # Use strict=False if adding/removing heads
      print("  Model state loaded.")

      if 'optimizer_state_dict' in checkpoint:
        try: optimizer.load_state_dict(checkpoint['optimizer_state_dict']); print("  Optimizer state loaded.")
        except: print("  Warning: Could not load optimizer state.")
      if 'epoch' in checkpoint:
        start_epoch = checkpoint['epoch'] + 1
        print(f"  Resuming from epoch {start_epoch}")
      if 'best_val_metric' in checkpoint:
        best_val_metric = checkpoint['best_val_metric']
        print(f"  Best previous metric: {best_val_metric:.4f}")
      if scaler and 'scaler_state_dict' in checkpoint:
        scaler.load_state_dict(checkpoint['scaler_state_dict'])
        print("  Scaler state loaded.")

    else:
      model.load_state_dict(checkpoint, strict=False)
      print("Loaded model state_dict directly.")

    del checkpoint
    torch.cuda.empty_cache()

  except Exception as e:
    print(f"Error loading checkpoint: {e}. Training from scratch.")
    start_epoch = 1
    best_val_metric = float('inf')

# %%
def train_epoch(model, loader, optimizer, scaler, device, cfg):
  model.train()

  total_loss = 0.0
  task_losses = {task: 0.0 for task in cfg.TASKS}
  num_samples = 0

  criterion_reg = nn.MSELoss()
  criterion_cls = nn.CrossEntropyLoss()
  pbar = tqdm(loader, desc=f"Epoch {epoch} Training", leave=False, dynamic_ncols=True)

  for batch_data in pbar:
    if batch_data is None:
      continue
    wav, targets = batch_data
    wav = wav.to(device)

    if torch.isnan(wav).any():
      print(f"CRITICAL NAN DETECTED in batched 'wav' tensor at start of train_epoch.")

    targets = {k: v.to(device) for k, v in targets.items()}
    optimizer.zero_grad()

    with torch.amp.autocast(device_type=cfg.DEVICE, enabled=(scaler is not None)):
      predictions = model(wav)

      combined_loss = 0.0
      current_batch_losses = {}

      for task_name, task_info in cfg.TASKS.items():
        pred = predictions[task_name]
        target = targets[task_name]
        loss = criterion_reg(pred, target) if task_info['type'] == 'regression' else criterion_cls(pred, target)
        weight = task_info['loss_weight']
        combined_loss += weight * loss
        current_batch_losses[task_name] = loss.item()
        task_losses[task_name] += loss.item() * wav.size(0)

    if scaler:
      scaler.scale(combined_loss).backward()
      if cfg.GRADIENT_CLIP_VAL > 0:
        scaler.unscale_(optimizer)

      torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.GRADIENT_CLIP_VAL)
      scaler.step(optimizer)
      scaler.update()

    else:
      combined_loss.backward()
      if cfg.GRADIENT_CLIP_VAL > 0:
        torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.GRADIENT_CLIP_VAL)

      optimizer.step()


    valid_samples_in_batch = wav.size(0)
    total_loss += combined_loss.item() * valid_samples_in_batch
    num_samples += valid_samples_in_batch

    pbar_postfix = {f"{k[:3]}_L": f"{v:.2f}" for k, v in current_batch_losses.items()}
    pbar_postfix["Total_L"] = f"{combined_loss.item():.3f}"
    pbar.set_postfix(pbar_postfix)


  avg_loss = total_loss / num_samples if num_samples > 0 else 0.0
  avg_task_losses = {k: v / num_samples if num_samples > 0 else 0.0 for k, v in task_losses.items()}
  return avg_loss, avg_task_losses

# %%
def evaluate(model, loader, device, cfg):
  model.eval()

  all_targets = {task: [] for task in cfg.TASKS}
  all_preds = {task: [] for task in cfg.TASKS}

  pbar = tqdm(loader, desc="Evaluating", leave=False, dynamic_ncols=True)
  with torch.no_grad():
    for batch_data in pbar:
      if batch_data is None:
        print("batch_data is None")
        continue

      wav, targets = batch_data
      wav = wav.to(device)
      predictions = model(wav)
      for task_name, task_info in cfg.TASKS.items():
        pred = predictions[task_name].cpu()
        target = targets[task_name].cpu()

        if task_info['type'] == 'regression':
          mean=cfg.NORM_STATS[task_name]['mean']
          std=cfg.NORM_STATS[task_name]['std']
          pred_denorm = (pred * std) + mean
          target_denorm = (target * std) + mean
          all_preds[task_name].extend(pred_denorm.tolist())
          all_targets[task_name].extend(target_denorm.tolist())

        else:     # classification
          pred_labels = torch.argmax(pred, dim=1)
          all_preds[task_name].extend(pred_labels.tolist())
          all_targets[task_name].extend(target.tolist())


  metrics = {}
  for task_name, task_info in cfg.TASKS.items():
      targets_np = np.array(all_targets[task_name])
      preds_np = np.array(all_preds[task_name])
      # print(all_targets)
      # print(all_preds)
      # print(targets_np)
      # print(preds_np)


      if len(targets_np) == 0:
        # print(f"Warning: No targets/preds for metric: {task_name}")
        continue
      if task_info['type'] == 'regression':
        metrics[f"{task_name}_mse"] = mean_squared_error(targets_np, preds_np)
      else: # classification
        metrics[f"{task_name}_acc"] = accuracy_score(targets_np, preds_np)

  return metrics

# %% [markdown]
# if the train losses are coming out to be NaN, the kindly restart the session and run all cells

# %%
print(f"Running from epoch {start_epoch} to {cfg.EPOCHS}.")

for epoch in range(start_epoch, cfg.EPOCHS + 1):
  epoch_start_time = time.time()
  avg_train_loss, avg_task_losses = train_epoch(model, train_loader, optimizer, scaler, cfg.DEVICE, cfg)
  val_metrics = evaluate(model, val_loader, cfg.DEVICE, cfg)
  epoch_duration = time.time() - epoch_start_time

  task_loss_str = " | ".join([f"{k[:3]}L={v:.3f}" for k, v in avg_task_losses.items()])
  val_metrics_str = " | ".join([f"{k}={v:.3f}" for k, v in val_metrics.items()])
  print(f"Epoch {epoch}/{cfg.EPOCHS} [{epoch_duration:.1f}s] => Loss: {avg_train_loss:.4f} | {task_loss_str}")
  print(f"Validation => {val_metrics_str}")

  current_val_metric = val_metrics.get('age_mse', float('inf'))

  if current_val_metric < best_val_metric:
    best_val_metric = current_val_metric
    print(f"  Saving best model (Age MSE={best_val_metric:.3f}) to {cfg.CKPT_PATH}")
    save_content = {
          'epoch': epoch,
          'model_state_dict': model.state_dict(),
          'optimizer_state_dict': optimizer.state_dict(),
          'best_val_metric': best_val_metric,
          'config': {k: v for k, v in vars(cfg).items() if not k.startswith('__') and type(v) in [str, int, float, bool, dict, list]},
          'norm_stats': cfg.NORM_STATS,
          'gender_map': cfg.GENDER_MAP
          # 'ethnicity_map': cfg.ETHNICITY_MAP
      }
    if scaler:
      save_content['scaler_state_dict'] = scaler.state_dict()
    torch.save(save_content, cfg.CKPT_PATH)
# Out:
# Running from epoch 1 to 50.
# Epoch 1 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 1/50 [149.9s] => Loss: 2.5850 | ageL=0.922 | GenL=0.680 | heiL=0.983
# Validation => age_mse=74.861 | Gender_acc=0.655 | height_mse=95.609
#   Saving best model (Age MSE=74.861) to ./sps_model.pth
# Epoch 2 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 2/50 [147.9s] => Loss: 2.5461 | ageL=0.921 | GenL=0.642 | heiL=0.982
# Validation => age_mse=74.577 | Gender_acc=0.655 | height_mse=96.237
#   Saving best model (Age MSE=74.577) to ./sps_model.pth
# Epoch 3 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 3/50 [147.2s] => Loss: 2.5086 | ageL=0.922 | GenL=0.605 | heiL=0.982
# Validation => age_mse=74.842 | Gender_acc=0.655 | height_mse=96.622
# Epoch 4 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 4/50 [147.4s] => Loss: 2.4962 | ageL=0.922 | GenL=0.592 | heiL=0.982
# Validation => age_mse=74.708 | Gender_acc=0.655 | height_mse=96.456
# Epoch 5 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 5/50 [147.4s] => Loss: 2.4936 | ageL=0.921 | GenL=0.591 | heiL=0.982
# Validation => age_mse=74.643 | Gender_acc=0.655 | height_mse=96.753
# Epoch 6 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 6/50 [147.6s] => Loss: 2.4939 | ageL=0.922 | GenL=0.589 | heiL=0.983
# Validation => age_mse=74.846 | Gender_acc=0.655 | height_mse=96.606
# Epoch 7 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 7/50 [147.4s] => Loss: 2.4924 | ageL=0.922 | GenL=0.589 | heiL=0.982
# Validation => age_mse=74.786 | Gender_acc=0.655 | height_mse=96.617
# Epoch 8 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 8/50 [148.6s] => Loss: 2.4895 | ageL=0.921 | GenL=0.587 | heiL=0.981
# Validation => age_mse=74.734 | Gender_acc=0.655 | height_mse=96.206
# Epoch 9 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 9/50 [148.5s] => Loss: 2.4937 | ageL=0.922 | GenL=0.590 | heiL=0.982
# Validation => age_mse=74.790 | Gender_acc=0.655 | height_mse=96.285
# Epoch 10 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 10/50 [151.0s] => Loss: 2.4918 | ageL=0.922 | GenL=0.589 | heiL=0.981
# Validation => age_mse=74.684 | Gender_acc=0.655 | height_mse=96.669
# Epoch 11 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 11/50 [150.4s] => Loss: 2.4906 | ageL=0.921 | GenL=0.588 | heiL=0.981
# Validation => age_mse=74.752 | Gender_acc=0.655 | height_mse=96.502
# Epoch 12 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 12/50 [150.1s] => Loss: 2.4910 | ageL=0.922 | GenL=0.588 | heiL=0.981
# Validation => age_mse=74.784 | Gender_acc=0.655 | height_mse=96.459
# Epoch 13 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 13/50 [148.9s] => Loss: 2.4919 | ageL=0.922 | GenL=0.589 | heiL=0.981
# Validation => age_mse=74.813 | Gender_acc=0.655 | height_mse=96.662
# Epoch 14 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 14/50 [148.9s] => Loss: 2.4917 | ageL=0.921 | GenL=0.589 | heiL=0.981
# Validation => age_mse=74.767 | Gender_acc=0.655 | height_mse=96.406
# Epoch 15 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 15/50 [148.8s] => Loss: 2.4909 | ageL=0.921 | GenL=0.588 | heiL=0.982
# Validation => age_mse=74.749 | Gender_acc=0.655 | height_mse=96.671
# Epoch 16 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 16/50 [149.2s] => Loss: 2.4926 | ageL=0.922 | GenL=0.589 | heiL=0.981
# Validation => age_mse=74.713 | Gender_acc=0.655 | height_mse=96.478
# Epoch 17 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 17/50 [148.3s] => Loss: 2.4918 | ageL=0.922 | GenL=0.589 | heiL=0.982
# Validation => age_mse=74.765 | Gender_acc=0.655 | height_mse=96.552
# Epoch 18 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 18/50 [148.4s] => Loss: 2.4911 | ageL=0.921 | GenL=0.588 | heiL=0.981
# Validation => age_mse=74.781 | Gender_acc=0.655 | height_mse=96.484
# Epoch 19 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 19/50 [147.8s] => Loss: 2.4913 | ageL=0.922 | GenL=0.588 | heiL=0.982
# Validation => age_mse=74.759 | Gender_acc=0.655 | height_mse=96.546
# Epoch 20 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/36 [00:00<?, ?it/s]
# Epoch 20/50 [148.4s] => Loss: 2.4925 | ageL=0.922 | GenL=0.589 | heiL=0.982
# Validation => age_mse=74.798 | Gender_acc=0.655 | height_mse=96.498
# Epoch 21 Training:   0%|          | 0/105 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-c2b978a6475f> in <cell line: 0>()
#       3 for epoch in range(start_epoch, cfg.EPOCHS + 1):
#       4   epoch_start_time = time.time()
# ----> 5   avg_train_loss, avg_task_losses = train_epoch(model, train_loader, optimizer, scaler, cfg.DEVICE, cfg)
#       6   val_metrics = evaluate(model, val_loader, cfg.DEVICE, cfg)
#       7   epoch_duration = time.time() - epoch_start_time
#
# <ipython-input-26-9248b9874358> in train_epoch(model, loader, optimizer, scaler, device, cfg)
#      55
#      56     valid_samples_in_batch = wav.size(0)
# ---> 57     total_loss += combined_loss.item() * valid_samples_in_batch
#      58     num_samples += valid_samples_in_batch
#      59
#
# KeyboardInterrupt:

# %%
if os.path.isfile(cfg.CKPT_PATH):
  print(f"Loading best model from: {cfg.CKPT_PATH}")
  try:
    ckpt = torch.load(cfg.CKPT_PATH, map_location=cfg.DEVICE)
    model.load_state_dict(ckpt.get('model_state_dict', ckpt), strict=False)

    del ckpt
    torch.cuda.empty_cache()
    gc.collect()

  except Exception as e:
    print(f"  Error loading best model: {e}. Evaluating current state.")

else:
  print(f"Warning: Best checkpoint '{cfg.CKPT_PATH}' not found. Evaluating final model state.")


if test_loader is None or len(test_loader.dataset) == 0:
  print("Skipping test evaluation: Test data empty.")

else:
  print("Running final evaluation...")
  test_metrics = evaluate(model, test_loader, cfg.DEVICE, cfg)

  print(f"-------------------------")
  print(f"Test Set Results:")
  for metric, value in test_metrics.items():
    print(f"  {metric.replace('_',' ').capitalize():<20}: {value:.3f}")
  print(f"-------------------------")
# Out:
# Loading best model from: ./sps_model.pth
#   Error loading best model: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL numpy._core.multiarray.scalar was not an allowed global by default. Please use `torch.serialization.add_safe_globals([scalar])` or the `torch.serialization.safe_globals([scalar])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.. Evaluating current state.
# Running final evaluation...
# Evaluating:   0%|          | 0/52 [00:00<?, ?it/s]
# -------------------------
# Test Set Results:
#   Age mse             : 72.888
#   Gender acc          : 0.659
#   Height mse          : 83.043
# -------------------------

# %% [markdown]
# ## Conclusion
#
# ### After training spsBiLSTM model on T4 GPU for 20 epochs (time taken = 1 hour 23 mins), the final evaluation metrics are:
#
# * RMSE Age = 8.53, implies on average model's guess on age is off by 8.5 years
#
# * RMSE Age = 9.11, implies on average model's guess on age is off by 9.11 cm
#
# * Gender accuracy = 65.9%
